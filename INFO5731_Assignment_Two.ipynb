# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/Assignments/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (20 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [Apple iPhone 11](https://www.amazon.com/Apple-iPhone-11-64GB-Unlocked/dp/B07ZPKF8RG/ref=sr_1_13?dchild=1&keywords=iphone+12&qid=1631721363&sr=8-13) on amazon.
#
# (2) Collect all User Reviews of the film [Shang-Chi and the Legend of the Ten Rings](https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3) from IMDB.
#
# (3) Collect all the abstracts research papers by using the query [smart health](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 10,000 tweets by using hashtag ["#blacklivesmatter"](https://twitter.com/hashtag/blacklivesmatter) from Twitter with the following requirements: Location (Texas), Time frame (2021-01-01 to 2021-09-01).

# %%
# Write your code here
# !pip install tweepy
#import the library used to query a website
import json
import csv
import tweepy
import re

def hashtag_search(consumer_key, consumer_secret, access_token, access_token_secret, hashtag):
  
  # create authentication for accessing Twitter
  auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  auth.set_access_token(access_token, access_token_secret)

  # initialize Tweepy API
  api = tweepy.API(auth, wait_on_rate_limit=True)

  # get the name of the spreadsheet we will write to
  fname = '_'.join(re.findall(r"#(\w+)", hashtag))

  # will collect 1000 posts
  numtweet = int(input('Enter the number of tweets that you want to collect: '))

  # open the spreadsheet we will write to
  with open('%s.csv' % (fname), 'w') as file:
      w = csv.writer(file)
      
      # write header row to spreadsheet
      w.writerow(['posted time', 'tweet text', 'user_name', 'location'])

      # for each tweet matching our hashtags, write relevant info to the spreadsheet
      for tweet in tweepy.Cursor(api.search, q=hashtag+' -filter:retweets', lang="en", tweet_mode='extended').items(numtweet):
            w.writerow([tweet.created_at, tweet.full_text.replace('\n',' ').encode('utf-8'), tweet.user.screen_name.encode('utf-8'), tweet.user.location.encode('utf-8')])

consumer_key = input('Consumer Key:  ')
consumer_secret= input('Consumer Secret: ')
access_token = input('Access Token: ')
access_token_secret = input('Access Token Secret: ')

hashtag = input("Enter the hashtag you want to scrape: ")

if __name__ == '__main__':
    hashtag_search(consumer_key, consumer_secret, access_token, access_token_secret, hashtag)
# Out:
# Requirement already satisfied: tweepy in c:\users\ttp0037\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from tweepy) (2.25.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Consumer Key:  p1bzwj5wvp6EWgBy9jvaN3llq
# Consumer Secret: MijsahV7ncQ4nvBDZN34YVXoDZ6a5buSmng7Kt1caJ4hMDfh9Z
# Access Token: 393052525-Nya0ZQ2l8fvUHjgbfUxuQeaLcJzI95QMhX9XFuup
# Access Token Secret: N8194oujcZmw676PaoiPrRk5rKax2CRl1yinyUGH8hvG2
# Enter the hashtag you want to scrape: #COVID19
# Enter the number of tweets that you want to collect: 1000

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points) Here is a [legal case](https://github.com/unt-iialab/info5731-fall2021/blob/main/assignments/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# (1) Basic feature extraction using text data
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# (2) Basic Text Pre-processing of text data
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# (3) Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above.
#
#
# (4) Advance Text Processing
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %%
# Write your code here

with open('01-05-1 Adams v Tanner.txt', encoding="mbcs") as file:
    texts = file.read()

texts.replace('\r',' ')
texts.replace('\n',' ')
# Out:
# 'ï»¿  5 Ala. 740 Supreme Court of Alabama. ADAMS v. TANNER AND HORTON. June Term, 1843. Synopsis WRIT of Error to the Circuit Court of Sumter. Â\xa0   West Headnotes (2)   [1] Chattel Mortgages Crops A growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time. 4 Cases that cite this headnote  [2] Creditorsâ€™ Remedies Lien and Priority Under St.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered. 5 Cases that cite this headnote  **1 This was a trial of the right of property under the statute. In November, 1840, an execution issued from the circuit court of Sumter, at the suit of the plaintiff in error, requiring the sheriff of that county, to make of the goods, &c., of Allen Harrison and others, the sum of thirty-seven hundred and seventy-seven 80-100 dollars, besides costs. This execution was levied on thirty bales of cotton, as the property of Allen Harrison, which was claimed, and a bond given to try the right. An issue was made up to try the question of the liability of the cotton to the plaintiffâ€™s execution, and submitted to a jury. On the trial, a bill of exceptions was sealed at the instance of the plaintiff. The plaintiff proved that he recovered his judgment in October, 1839; that an execution *741 was issued thereon on the 7th Nov. thereafter, and that alias and pluries fieri faciasâ€™, issued regularly up to the time levy was made; that the cotton levied on was growed on the plantation of Harrison, and cultivated by the hands in his service. It was proved by the claimants, by the production of a written contract, that Harrison, on the twenty-second of May, 1840, in consideration that the claimants were involved, as indorsers for Burton & Harrison of Sumter county, and were then exposed to an execution, amounting to upwards of fourteen thousand dollars, bargained and sold to the claimants all his growing crop of cotton &c., consisting of one hundred and twenty acres, &c. Allen Harrison promised and obliged himself to give up his crop to the use of the claimants at any time to save them from suffering as his indorsers; if the crop matured and was gathered he undertook to deliver the cotton in Gainesville. The claimants came from Tennessee, (where they resided) about the first of September, 1840, bringing with them three or four white laborers, and took possession of the crop and slaves, and with the latter, and white laborers, gathered the cotton, prepared it for market, and when levied on, it was in a ware-house in Gainesville. The plaintiff then proved by Harrison, that the claimants took possession of the crop, while he was absent, and disposed of it without his consent. It was admitted, that the contract was made in good faith. The court charged the jury, that the plaintiff had no lien by virtue of his judgment, and execution on the growing crop; that Harrison had a right to convey it, without being in any manner restrained by them; that the writing adduced, was a sale of the crop, but if it was not, and the lien of the fieri facias would have attached upon it, when gathered, yet if the claimants obtained possession on the first of September, and controlled the gathering of the crop, then no lien attached, and it was not subject to the levy. Attorneys and Law Firms R. H. SMITH, for the plaintiff, in error, made the following points.--1. The crop of Harrison, must, in May, 1840, have been in an immature state, and it is insisted, was not the subject of a sale. 2. By the common law, a growing crop could be levied on and sold, [1 Salk. Rep. 361; 1 Bos. & P. Rep. 307; 6 Eastâ€™s Rep. 604, note 1; 2 Johns. Rep. 418, 422; 7 Mass. Rep. 34,] and our statue, [[[Aik. Dig. Â§ 41, p. 167,] which forbids the levy of an *742 execution on a growing crop, is to receive a st ...

# %% [markdown]
# ## (1) Basic feature extraction using text data

# %%
# Number of sentences
print("Number of sentences:", texts.count('.'))

# Number of words
print('Number of words:', texts.count(' '))

# Number of characters
characters = [char for char in list(texts) if char != ' ']
print('Number of charcters: ', len(list(texts)))

# Average word length
words = texts.split()
average = sum(len(word) for word in words) / len(words)
print('Average word length: ',average)

# Number of Stopwords
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
print('Number of stopwords:', len([word for word in texts.split() if word in stopwords.words('english')]))

# Number of Special Characters
special_chars = '!@#$^&*ï»¿â€â€™'
tot = 0
for char in special_chars:
    count = len([word for word in texts.split(' ') if word.startswith(char)])
    tot += count
print('Number of special characters:', tot)

# Number of Numerics
numerics = len([x for x in list(texts) if x.isnumeric()])
print('Number of numerics:', numerics)

# Number of Uppercase Words
uppercase_words = len([word for word in texts.split() if word.isupper()])
print('Number of uppercase words:', uppercase_words)
# Out:
# Number of sentences: 291
# Number of words: 3574
# Number of charcters:  20543
# Average word length:  4.53141008358048
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ttp0037\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Number of stopwords: 1679
# Number of special characters: 37
# Number of numerics: 356
# Number of uppercase words: 88

# %% [markdown]
# ## (2) Basic Text Pre-processing of text data

# %%
# Write your code here

import pandas as pd

raw_data = pd.read_csv('assig2_data.csv')
raw_data = pd.DataFrame(raw_data)
raw_data.columns = ['tweet']
train = pd.read_csv('assig2_data.csv')
train.columns = ['tweet']
train
# Out:
#                                                  tweet
# 0                                           5 Ala. 740
# 1                            Supreme Court of Alabama.
# 2                                                ADAMS
# 3                                                   v.
# 4                                   TANNER AND HORTON.
# ..                                                 ...
# 143            There are no Filings for this citation.
# 144                                 Negative Treatment
# 145  There are no Negative Treatment results for th...
# 146                                            History
# 147    There are no History results for this citation.
#
# [148 rows x 1 columns]

# %%
# Lower casing
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x.lower() for x in x.split()))
train['tweet']
# Out:
# 0                                             5 ala. 740
# 1                              supreme court of alabama.
# 2                                                  adams
# 3                                                     v.
# 4                                     tanner and horton.
#                              ...
# 143              there are no filings for this citation.
# 144                                   negative treatment
# 145    there are no negative treatment results for th...
# 146                                              history
# 147      there are no history results for this citation.
# Name: tweet, Length: 148, dtype: object

# %%
# Removing Punctuations
train['tweet'] = train['tweet'].str.replace('[^\w\s]','')
train['tweet']
# Out:
# <ipython-input-39-b328148d1209>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train['tweet'] = train['tweet'].str.replace('[^\w\s]','')
# 0                                              5 ala 740
# 1                               supreme court of alabama
# 2                                                  adams
# 3                                                      v
# 4                                      tanner and horton
#                              ...
# 143               there are no filings for this citation
# 144                                   negative treatment
# 145    there are no negative treatment results for th...
# 146                                              history
# 147       there are no history results for this citation
# Name: tweet, Length: 148, dtype: object

# %%
# Removing Stopwords
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train['tweet']
# Out:
# 0                                5 ala 740
# 1                    supreme court alabama
# 2                                    adams
# 3                                        v
# 4                            tanner horton
#                       ...
# 143                       filings citation
# 144                     negative treatment
# 145    negative treatment results citation
# 146                                history
# 147               history results citation
# Name: tweet, Length: 148, dtype: object

# %%
# frequent word removal
# check the 10 most frequently occurring words in our text data
freq = pd.Series(' '.join(train['tweet']).split()).value_counts()[:10]

# remove
freq = list(freq.index)
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['tweet']
# Out:
# 0                                5 ala 740
# 1                          supreme alabama
# 2                                    adams
# 3
# 4                            tanner horton
#                       ...
# 143                       filings citation
# 144                     negative treatment
# 145    negative treatment results citation
# 146                                history
# 147               history results citation
# Name: tweet, Length: 148, dtype: object

# %%
# rare word removal
freq = pd.Series(' '.join(train['tweet']).split()).value_counts()[-10:]
freq = list(freq.index)
train['tweet'] = train['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['tweet']
# Out:
# 0                                5 ala 740
# 1                          supreme alabama
# 2                                    adams
# 3
# 4                            tanner horton
#                       ...
# 143                       filings citation
# 144                     negative treatment
# 145    negative treatment results citation
# 146                                history
# 147               history results citation
# Name: tweet, Length: 148, dtype: object

# %%
# stemming
from nltk.stem import PorterStemmer
num_rows = len(train.axes[0])
st = PorterStemmer()
train['tweet'][:num_rows].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
train['tweet']
# Out:
# 0                                5 ala 740
# 1                          supreme alabama
# 2                                    adams
# 3
# 4                            tanner horton
#                       ...
# 143                       filings citation
# 144                     negative treatment
# 145    negative treatment results citation
# 146                                history
# 147               history results citation
# Name: tweet, Length: 148, dtype: object

# %%
# Spelling Correction
from textblob import TextBlob
train['tweet'] = train['tweet'][:num_rows].apply(lambda x: str(TextBlob(x).correct()))
train['tweet']
# Out:
# 0                                 5 all 740
# 1                           supreme alabama
# 2                                     adams
# 3
# 4                             manner norton
#                        ...
# 143                        filing situation
# 144                      negative treatment
# 145    negative treatment results situation
# 146                                 history
# 147               history results situation
# Name: tweet, Length: 148, dtype: object

# %%
# Lemmetization
from textblob import Word
# import nltk
nltk.download('wordnet')
train['tweet'] = train['tweet'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
train['tweet']
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ttp0037\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0                                5 all 740
# 1                          supreme alabama
# 2                                     adam
# 3
# 4                            manner norton
#                       ...
# 143                       filing situation
# 144                     negative treatment
# 145    negative treatment result situation
# 146                                history
# 147               history result situation
# Name: tweet, Length: 148, dtype: object

# %%
# Tokenization
import nltk
TextBlob(train['tweet'][1]).words
train['tweet']
# Out:
# 0                                5 all 740
# 1                          supreme alabama
# 2                                     adam
# 3
# 4                            manner norton
#                       ...
# 143                       filing situation
# 144                     negative treatment
# 145    negative treatment result situation
# 146                                history
# 147               history result situation
# Name: tweet, Length: 148, dtype: object

# %% [markdown]
# ## (3) Save all the clean sentences to a csv file

# %%
# Save to .csv file
import pandas as pd
new_data = pd.concat([raw_data['tweet'], train['tweet']], axis = 1, join = 'inner')
new_data.columns = ['raw_data', 'clean_data']
new_data
# Out:
#                                               raw_data  \
# 0                                           5 Ala. 740
# 1                            Supreme Court of Alabama.
# 2                                                ADAMS
# 3                                                   v.
# 4                                   TANNER AND HORTON.
# ..                                                 ...
# 143            There are no Filings for this citation.
# 144                                 Negative Treatment
# 145  There are no Negative Treatment results for th...
# 146                                            History
# 147    There are no History results for this citation.
#
#                               clean_data
# 0                              5 all 740
# 1                        supreme alabama
# 2                                   adam
# 3
# 4                          manner norton
# ..                                   ...
# 143                     filing situation
# 144                   negative treatment
# 145  negative treatment result situation
# 146                              history
# 147             history result situation
#
# [148 rows x 2 columns]

# %% [markdown]
# ## (4) Advance Text Processing

# %%
import numpy as np
import pandas as pd

# Calculate the term frequency of all the terms
tf1 = (new_data['clean_data'][0:num_rows]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf1.columns = ['words','term_frequency']
tf1
# Out:
#         words  term_frequency
# 0         all            17.0
# 1           5             8.0
# 2         740             2.0
# 3     supreme             1.0
# 4     alabama             1.0
# ..        ...             ...
# 769       six             1.0
# 770       let             1.0
# 771    filing             2.0
# 772  negative             2.0
# 773   history             2.0
#
# [774 rows x 2 columns]

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
# add appropriate words that will be ignored in the analysis
ADDITIONAL_STOPWORDS = ['covfefe']

def basic_clean(text):
  wnl = nltk.stem.WordNetLemmatizer()
  stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
  text = (unicodedata.normalize('NFKD', text)
    .encode('ascii', 'ignore')
    .decode('utf-8', 'ignore')
    .lower())
  words = re.sub(r'[^\w\s]', '', text).split()
  return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
words = basic_clean(''.join(str(new_data['clean_data'].tolist())))

# %%
# Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.#

print('Top 10 1-gram:')
(pd.Series(nltk.ngrams(words,1)))[0:10]
# Out:
# Top 10 1-gram:
# 0          (5,)
# 1        (740,)
# 2    (supreme,)
# 3    (alabama,)
# 4       (adam,)
# 5     (manner,)
# 6     (norton,)
# 7       (june,)
# 8       (term,)
# 9       (1843,)
# dtype: object

# %%
print('Top 10 2-gram:')
(pd.Series(nltk.ngrams(words,2)))[0:10]
# Out:
# Top 10 2-gram:
# 0              (5, 740)
# 1        (740, supreme)
# 2    (supreme, alabama)
# 3       (alabama, adam)
# 4        (adam, manner)
# 5      (manner, norton)
# 6        (norton, june)
# 7          (june, term)
# 8          (term, 1843)
# 9       (1843, sycosis)
# dtype: object

# %%
print('Top 10 3-gram:')
(pd.Series(nltk.ngrams(words,3)))[0:10]
# Out:
# Top 10 3-gram:
# 0           (5, 740, supreme)
# 1     (740, supreme, alabama)
# 2    (supreme, alabama, adam)
# 3     (alabama, adam, manner)
# 4      (adam, manner, norton)
# 5      (manner, norton, june)
# 6        (norton, june, term)
# 7          (june, term, 1843)
# 8       (term, 1843, sycosis)
# 9       (1843, sycosis, writ)
# dtype: object

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in c:\users\ttp0037\anaconda3\lib\site-packages (3.1.3)
# Collecting spacy
#   Downloading spacy-3.2.1-cp38-cp38-win_amd64.whl (12.2 MB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.13-cp38-cp38-win_amd64.whl (1.0 MB)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (0.6.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: setuptools in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (52.0.0.post20210125)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (2.4.1)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (1.20.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (20.9)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: jinja2 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ttp0037\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ttp0037\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: thinc, spacy-loggers, langcodes, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.10
#     Uninstalling thinc-8.0.10:
#       Successfully uninstalled thinc-8.0.10
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.1.3
#     Uninstalling spacy-3.1.3:
#       Successfully uninstalled spacy-3.1.3
# Successfully installed langcodes-3.3.0 spacy-3.2.1 spacy-loggers-1.0.1 thinc-8.0.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.1.0 requires spacy<3.2.0,>=3.1.0, but you have spacy 3.2.1 which is incompatible.
# en-core-web-lg 3.1.0 requires spacy<3.2.0,>=3.1.0, but you have spacy 3.2.1 which is incompatible.

# %% [markdown]
# ## (1) Parts of Speech (POS) Tagging

# %%
# load english language model
import spacy
nlp = spacy.load('en_core_web_sm',disable=['ner','textcat'])


# create spacy 
doc = nlp(str(words))
noun = 0
verb = 0
adj = 0
adv = 0
for token in doc:
    print(token.text,'->',token.pos_)
    if token.pos_ == 'NOUN':
      noun = noun+1
    elif token.pos_ == 'VERB':
      verb = verb+1
    elif token.pos_ == 'ADJ':
      adj = adj+1
    elif token.pos_ == 'ADV':
      adv = adv+1
    else:
      pass
print("The total nouns: ", noun)
print("The total verbs: ", verb)
print("The total adjectives: ", adj)
print("The total adverbs: ", adv)
# Out:
# C:\Users\ttp0037\Anaconda3\lib\site-packages\spacy\util.py:833: UserWarning: [W095] Model 'en_core_web_sm' (3.1.0) was trained with spaCy v3.1 and may not be 100% compatible with the current version (3.2.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# [ -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 740 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# supreme -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# alabama -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# adam -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# manner -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# norton -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# june -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1843 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sycosis -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# writ -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# error -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sumter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# west -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# headnotes -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chattel -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mortgage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# crop -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# existence -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subjectmatter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mortgage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# pas -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# interest -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# vest -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# either -> CCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# immediately -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# future -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 4 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# case -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cite -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# headnote -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# creditor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# remedy -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# priority -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# st1821 -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prohibiting -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attache -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# favor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attach -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> NUM
# , -> PUNCT
# ' -> PUNCT
# case -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cite -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# headnote -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# trial -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# statute -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# november -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1840 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# issued -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sumter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# error -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# requiring -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sheriff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# county -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# make -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# good -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# allen -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# others -> NOUN
# ' -> PART
# , -> PUNCT
# ' -> PUNCT
# sum -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thirtyseven -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hundred -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seventyseven -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 80100 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dollar -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# besides -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cost -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thirty -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# allen -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# claimed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bond -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# given -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# try -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# issue -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# try -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# question -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# liability -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# submitted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jury -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# trial -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bill -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# exception -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sealed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# instance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# proved -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# recovered -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# judgment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# october -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1839 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 741 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# issued -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thereon -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# th -> INTJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# nov -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thereafter -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# alias -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plunies -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fiery -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# facial -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# issued -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# regularly -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growled -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plantation -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cultivated -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hand -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# service -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# proved -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# production -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# written -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# twentysecond -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1840 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consideration -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# involved -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# button -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sumter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# county -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# exposed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# amounting -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upwards -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fourteen -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thousand -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dollar -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bargained -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sold -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consisting -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# one -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hundred -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# twenty -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# acre -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# allen -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# promised -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# obliged -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# give -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# use -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# save -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suffering -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# matured -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# undertook -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# deliver -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gainesville -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# came -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tennessee -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# resided -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# first -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# september -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1840 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bringing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# three -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# four -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# white -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# laborer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# took -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# slave -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# latter -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# white -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# laborer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prepared -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# market -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# warehouse -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gainesville -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# proved -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# took -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# absent -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# disposed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# without -> ADP
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consent -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# admitted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# good -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# faith -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# charged -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jury -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# virtue -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# judgment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# convey -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# without -> ADP
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# manner -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# restrained -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# writing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# added -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fiery -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# facial -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# would -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attached -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# yet -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# obtained -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# first -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# september -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# controlled -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gathering -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attached -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subject -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attorney -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# firm -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# r -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# h -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# smith -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# error -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# following -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# point -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# must -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1840 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# immature -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# state -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# insisted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subject -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# common -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# could -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sold -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# talk -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 361 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# boy -> INTJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# p -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 307 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 6 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# east -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 604 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# note -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 422 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 7 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mass -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 34 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# statue -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ask -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dig -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 41 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# p -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 167 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# forbids -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 742 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# receive -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# strict -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# construction -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# merely -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# inhibit -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attache -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mature -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# purport -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# convey -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mere -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# executor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# agreement -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# requiring -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# done -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# order -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# invest -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# con -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 112 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> NUM
# 207 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 338 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 424 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# went -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 26 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 13 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 235 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 8 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 693 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# done -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# matter -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# liable -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seized -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harrison -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debt -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chancery -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# would -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# compel -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# specific -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# performance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# instance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 4 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# charge -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# also -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# objectionable -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# deciding -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# disputed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fact -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# w -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# murphy -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# w -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# g -> INTJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jones -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendantcited -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1821 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ask -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dig -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 167 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# declares -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# lawful -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# planted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contended -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attached -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# favor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# restrained -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# making -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# destroyed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# injunction -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# take -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# away -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# short -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whenever -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# temporarily -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suspended -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# withdrawn -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# lost -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# foot -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 216 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wash -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 66 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 4 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 130 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# admitted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# good -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# faith -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# severance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# removal -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gave -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# latter -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# good -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# title -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# creditor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# former -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# opinion -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# soldier -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# j -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doubt -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# existence -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subject -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# matter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mortgage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# posse -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# interest -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# vest -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# either -> CCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# immediately -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# future -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# proposition -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# frequently -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# assumed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# unquestionable -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# point -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# inquiry -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# generally -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whether -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# statute -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fraud -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 29 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chas -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mere -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chattel -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# transferrable -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# patrol -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# without -> ADP
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# writing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chatty -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# con -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2412 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 332 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# foot -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 422 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# stewart -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doughy -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 9 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 112 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 743 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# austin -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# lawyer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 9 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cow -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 39 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# see -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# also -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# lee -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# alton -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# last -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# set -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bill -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# exception -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# think -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# evidence -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rather -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mortgage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# absolute -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# recite -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# involved -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mercantile -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# firm -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# partner -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upwards -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fourteen -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thousand -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dollar -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# estate -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sheriff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hand -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# conveyance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# corn -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# oat -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grant -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# agrees -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# give -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# use -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prevent -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# injury -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# might -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# divested -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# interest -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# vested -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# discharging -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# liability -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# judgment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# creditor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# might -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# satisfied -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sold -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fiery -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# facial -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consider -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# writing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# assert -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mortgage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# power -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# year -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# unless -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# relieved -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# engagement -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# pretended -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# liability -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# satisfied -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# admitted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# party -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# acted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# good -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# faith -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dry -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# question -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whether -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# shall -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prevail -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# assuming -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# present -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# operate -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# planted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# previous -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1840 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# inquire -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whether -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# interest -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# could -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sold -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# previous -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taken -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prepared -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# market -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# removed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# warehouse -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# insisted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# trespass -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# acquired -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# absence -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# without -> ADP
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consent -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# given -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# conceding -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# truth -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fact -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# stated -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bill -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# exception -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# think -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# follow -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# nullify -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# must -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# considered -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# never -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# interfered -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contains -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# express -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# undertaking -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# give -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# might -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# require -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indemnity -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# took -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# absence -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grant -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# though -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# without -> ADP
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consent -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subsequently -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# acquiesced -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# inference -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# would -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# necessary -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# approved -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taking -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# clear -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 744 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seen -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# time -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# nothing -> PRON
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mere -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# equitable -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# redeem -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# paying -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debt -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indorsed -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# coupled -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# equity -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# naked -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# equity -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# held -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# can -> AUX
# not -> PART
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# reached -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ordinary -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# person -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# elliott -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hayfield -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# porter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rep -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 182 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# brings -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# u -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# back -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# question -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whether -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defeat -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mortgage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# frequently -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# looted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whether -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# common -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# corn -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seized -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fiery -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# facial -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mr -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dane -> INTJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# remarking -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# point -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# say -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# american -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# editor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bacon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# abridgment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# say -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wheat -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ground -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chattel -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subject -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taken -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sheriff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suffer -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grow -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harvest -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cut -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sell -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# perhaps -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sell -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# purchaser -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# entitled -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# enter -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# purpose -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cutting -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# carrying -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# away -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# city -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# foot -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ut -> INTJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# supra -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# also -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# pole -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# talk -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 368 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# boy -> INTJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# p -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 397 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 6 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# east -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 604 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# n -> CCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# foot -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seems -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# support -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# position -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# unripe -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wheat -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# corn -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taken -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# editor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# state -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# nothing -> PRON
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taken -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# can -> AUX
# not -> PART
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sold -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# position -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# say -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# learned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# commentator -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doubt -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# unnecessary -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consider -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# matter -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# stand -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# common -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# first -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# section -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1821 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prevent -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sheriff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# officer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levying -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# execution -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# certain -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# case -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# enacts -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# shall -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# lawful -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sheriff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# officer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# writ -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fiery -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# facial -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# planted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debtor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# person -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# issue -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ask -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dig -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 167 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# express -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# inhibition -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# remains -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ground -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# severed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# soil -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# owes -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growth -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# respect -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thus -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# situated -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attach -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# instant -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# placed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hand -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# officer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# effect -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# keeping -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# abeyance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# operate -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prevent -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debtor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# disposing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attache -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# give -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# creditor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sold -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# satisfy -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 745 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# judgment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# intimately -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# connected -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# latter -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taken -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# away -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suspended -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# effect -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# common -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# destruction -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# former -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# principle -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# fully -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# established -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mason -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hurtell -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# president -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# c -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bank -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# united -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# state -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# assigned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# situation -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contained -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# opinion -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# also -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# opinion -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wood -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mary -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# et -> PRON
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# al -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# decided -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# last -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# competent -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# legislature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# made -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# unlawful -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# particular -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# condition -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# changed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# still -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# give -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# continuing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# can -> AUX
# not -> PART
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doubted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# nothing -> PRON
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# question -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# indicate -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# intention -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# object -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# merely -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suspend -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# would -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# easy -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# said -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# declaring -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# statute -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# totidem -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# shall -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# levied -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# legislature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# must -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# supposed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# meant -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# expressed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# act -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# induced -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doubt -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# existed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# common -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# intended -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# remove -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doubt -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# declaring -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# future -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# create -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# authorize -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# existed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# silent -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# idea -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attached -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# planted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# soon -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# delivered -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sheriff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# though -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# postponed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# severance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# took -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# place -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attempted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# deduced -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# last -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# word -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# section -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# viz -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# word -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# can -> AUX
# not -> PART
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# principle -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# construction -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# regarded -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# potent -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# give -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# introspective -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# effect -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# refer -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# would -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# postpone -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# relate -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# postpone -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# event -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# take -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# place -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 4 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# planted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# expressly -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# taken -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# away -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# statute -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# connected -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# consequent -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# upon -> SCONJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# never -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attache -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# severance -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# make -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# unquestionable -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# title -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# coupled -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# possession -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# paramount -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# could -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# exert -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# judge -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mistaken -> ADJ
# ' -> PUNCT
# ...
# , -> PUNCT
# ' -> PUNCT
# animal -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# legislature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# protection -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debtor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# forbidden -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# plaintiff -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sell -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debtor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# condition -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bring -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# value -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# yet -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# permit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# debtor -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# voluntarily -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# submit -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sacrifice -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# benefit -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# effect -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gift -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# defendant -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# provided -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gather -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# disposed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# condition -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# feel -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thorough -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# conviction -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# intention -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# legislature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# secure -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# loss -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# prohibiting -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# temporary -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# suspension -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sell -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ceased -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# situation -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 740 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1843 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 284 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# end -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# document -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2019 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thomson -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# renter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# claim -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# original -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# u -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# government -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# work -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# biting -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# reference -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 9 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# treatment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# title -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# date -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# type -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# depth -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# headnotes -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hooker -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jones -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# army -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 55 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 266 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 271 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grover -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# conversion -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# count -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# appeal -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tried -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# j -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# scaffold -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dec -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1876 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# german -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# burr -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# co -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# marshall -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 47 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 362 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 376 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grover -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# conversion -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# appeal -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# city -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# montgomery -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tried -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cunningham -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jan -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1872 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# gibb -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# manner -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 45 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 329 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 334 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# banishment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wage -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# waiter -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# exemption -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# appeal -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# city -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# montgomery -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tried -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cunningham -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jan -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1871 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 4 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mckenzie -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ample -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 31 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 526 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 527 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# trial -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# property -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# appeal -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# harbour -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tried -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jan -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1858 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# evans -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# later -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 21 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 333 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 335 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# error -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# autauga -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tried -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# b -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# moore -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# run -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1852 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 6 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# dewey -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# woman -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 8 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cal -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 145 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 147 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cal -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# judgment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# jacob -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cohens -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# reversed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# following -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# reason -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# finding -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# far -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cohens -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# concerned -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# july -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1857 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mentioned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 7 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tree -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# coat -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 65 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 256 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 258 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grover -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# conversion -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# three -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# bale -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cotton -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# appeal -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tried -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hon -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wm -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# l -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# whitlow -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# nov -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# term -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1880 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mentioned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 8 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# edward -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# thompson -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 4 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 913 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 914 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tenn -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# appeal -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# weakly -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# county -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# may -> AUX
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1887 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 9 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# crop -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subject -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seizure -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attachment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> NUM
# 103 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 464 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# generally -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# common -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# law -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# crop -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# raised -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# annual -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# planting -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# still -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attached -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# soil -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# regarded -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# personal -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# chattel -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# subject -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# seizure -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# attachment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1936 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# table -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# authority -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# treatment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# reference -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# title -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# type -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# depth -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# quoted -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# page -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# number -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mentioned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# austin -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# lawyer -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 9 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cow -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 39 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sup -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1828 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# patrol -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# evidence -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# admissible -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contradict -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# substantially -> ADV
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# written -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# contract -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# quitclaimed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# land -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# w -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wheat -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# growing -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# reserving -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cited -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# person -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# hayfield -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 5 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# port -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 182 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1837 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# writ -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# error -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# circuit -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# tuskaloosa -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# mentioned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 3 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# stewart -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# doughy -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 9 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# john -> PROPN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 108 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# sup -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 1812 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# let -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# b -> X
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# farm -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# six -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# year -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# agreed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# render -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# yield -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# pay -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# one -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# half -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# wheat -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# rye -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# corn -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# grain -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# raised -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# farm -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# year -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# 2 -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# filing -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# filing -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# situation -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# negative -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# treatment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# negative -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# treatment -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# result -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# situation -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# history -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# history -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# result -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# situation -> NOUN
# ' -> PUNCT
# ] -> PUNCT
# The total nouns:  617
# The total verbs:  406
# The total adjectives:  133
# The total adverbs:  52

# %%
# !pip install benepar
import spacy
import spacy.cli
import benepar
from nltk.tree import Tree
spacy.cli.download('en_core_web_lg')
nlp = spacy.load('en_core_web_lg')
benepar.download('benepar_en2')
nltk.download('punkt')
# Out:
# Requirement already satisfied: benepar in c:\users\ttp0037\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: nltk>=3.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (3.6.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (1.10.0)
# Requirement already satisfied: spacy>=2.0.9 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (3.2.1)
# Requirement already satisfied: protobuf in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (3.19.1)
# Requirement already satisfied: transformers[tokenizers,torch]>=4.2.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (4.13.0)
# Requirement already satisfied: tokenizers>=0.9.4 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (0.10.3)
# Requirement already satisfied: torch-struct>=0.5 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (0.5)
# Requirement already satisfied: sentencepiece>=0.1.91 in c:\users\ttp0037\anaconda3\lib\site-packages (from benepar) (0.1.96)
# Requirement already satisfied: regex in c:\users\ttp0037\anaconda3\lib\site-packages (from nltk>=3.2->benepar) (2021.4.4)
# Requirement already satisfied: joblib in c:\users\ttp0037\anaconda3\lib\site-packages (from nltk>=3.2->benepar) (1.0.1)
# Requirement already satisfied: click in c:\users\ttp0037\anaconda3\lib\site-packages (from nltk>=3.2->benepar) (7.1.2)
# Requirement already satisfied: tqdm in c:\users\ttp0037\anaconda3\lib\site-packages (from nltk>=3.2->benepar) (4.59.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (0.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (8.0.13)
# Requirement already satisfied: jinja2 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (0.8.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (0.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (2.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (1.0.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (20.9)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (0.6.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (2.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (1.20.1)
# Requirement already satisfied: setuptools in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (52.0.0.post20210125)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from spacy>=2.0.9->benepar) (3.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from packaging>=20.0->spacy>=2.0.9->benepar) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy>=2.0.9->benepar) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ttp0037\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.0.9->benepar) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (1.26.4)
# Requirement already satisfied: sacremoses in c:\users\ttp0037\anaconda3\lib\site-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (0.0.46)
# Requirement already satisfied: filelock in c:\users\ttp0037\anaconda3\lib\site-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (3.0.12)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ttp0037\anaconda3\lib\site-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (5.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\ttp0037\anaconda3\lib\site-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (0.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ttp0037\anaconda3\lib\site-packages (from jinja2->spacy>=2.0.9->benepar) (1.1.1)
# Requirement already satisfied: six in c:\users\ttp0037\anaconda3\lib\site-packages (from sacremoses->transformers[tokenizers,torch]>=4.2.2->benepar) (1.15.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# [nltk_data] Error loading benepar_en2: Package 'benepar_en2' not found
# [nltk_data]     in index
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ttp0037\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## (2) Constituency Parsing and Dependency Parsing

# %%
import nltk
benepar.download('benepar_en3')
# Out:
# [nltk_data] Downloading package benepar_en3 to
# [nltk_data]     C:\Users\ttp0037\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping models\benepar_en3.zip.
# True

# %%
#Constituency parsing 
parser = benepar.Parser("benepar_en3")

import benepar
parser= benepar.Parser("benepar_en3")
for sentence in new_data['clean_data']:
    try:
        tree = parser.parse(sentence)
        print(tree)
    except:
        print("There is no Parse Tree")
    continue
# Out:
# C:\Users\ttp0037\Anaconda3\lib\site-packages\torch\distributions\distribution.py:44: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# (TOP (NP (NP (CD 5)) (NP (DT all) (CD 740))))
# (TOP (NP (JJ supreme) (NN alabama)))
# (TOP (X (UH adam)))
# There is no Parse Tree
# (TOP (NP (NN manner) (RB norton)))
# (TOP (NP (NP (JJ june) (NN term)) (NP (CD 1843))))
# (TOP (NP (NN sycosis)))
# (TOP (NP (NML (NN writ) (NN error)) (NN circuit) (NN sumter)))
# There is no Parse Tree
# (TOP (NP (NN west) (NNS headnotes) (NP (CD 2))))
# (TOP (NP (CD 1)))
# (TOP (NP (NN chattel) (NN mortgage)))
# (TOP (NP (NN crop)))
# (TOP
#   (NP
#     (NP
#       (VBG growing)
#       (NN existence)
#       (NN subjectmatter)
#       (NN mortgage)
#       (NN contract))
#     (VB pass)
#     (NP (NML (NN interest) (NN vest)) (NN possession))
#     (ADVP (CC either) (RB immediately))
#     (NP (JJ future) (NN time))))
# (TOP (X (NP (CD 4) (NN case)) (VP (VB cite) (NP (NN headnote)))))
# (TOP (NP (CD 2)))
# (TOP (NP (NN creditor) (NN remedy)))
# (TOP (NP (NN priority)))
# (TOP
#   (S
#     (NP (CD st1821))
#     (VP
#       (VBG prohibiting)
#       (NP
#         (NP (NP (NN attache) (NN favor)) (PRP i))
#         (PP (DT a) (VBG growing) (NN attach))))))
# (TOP (S (NP (CD 5) (NN case)) (VP (VB cite) (NP (NN headnote)))))
# (TOP
#   (S
#     (NP
#       (NP (CD 1) (NN trial) (NN property) (NN statute))
#       (NP (NNP november) (CD 1840)))
#     (VBD issued)
#     (NP (NML (NN circuit) (NN sumter) (NN suit)) (NN plaintiff))
#     (NN error)
#     (VP
#       (VBG requiring)
#       (NP (NN sheriff) (NN county))
#       (VP (VB make) (ADJP (JJ good))))
#     (IN c)
#     (NN allen)
#     (NNP harrison)
#     (NNS others)
#     (NN sum)
#     (NP
#       (QP (CD thirtyseven) (CD hundred) (CD seventyseven))
#       (CD 80100)
#       (NN dollar))
#     (IN besides)
#     (NP
#       (NN cost)
#       (VBN levied)
#       (NML (CD thirty) (NN bale))
#       (NN cotton)
#       (NN property))
#     (NP (RB allen) (NNP harrison))
#     (VP
#       (VP
#         (VBD claimed)
#         (SBAR
#           (S
#             (NP (NN bond))
#             (VP
#               (VBN given)
#               (NP (NN try) (NN issue))
#               (VBN made)
#               (JJ try)
#               (NN question)))))
#       (NN liability)
#       (NP (NN cotton) (NN plaintiff))
#       (VP
#         (VBD submitted)
#         (NP (NN jury) (NN trial) (NN bill) (NN exception))
#         (VBN sealed)
#         (NN instance)
#         (NP (NN plaintiff) (NN plaintiff))
#         (VP
#           (VBD proved)
#           (NP (VBN recovered) (NN judgment))
#           (NP (NN october) (CD 1839) (CD 741))
#           (VP
#             (VP
#               (VBN issued)
#               (ADVP
#                 (RB thereon)
#                 (RB th)
#                 (NN nov)
#                 (ADVP (RB thereafter))))
#             (NP (NN alias) (NNS plunies) (JJ fiery) (NN facial))
#             (VP
#               (VP
#                 (VP
#                   (VBN issued)
#                   (ADVP (RB regularly))
#                   (NP (NN time))
#                   (VP
#                     (VBN made)
#                     (NP
#                       (NN cotton)
#                       (VBN levied)
#                       (VBN growled)
#                       (NN plantation))))
#                 (NN harrison)
#                 (VBN cultivated)
#                 (NN hand)
#                 (NN service))
#               (VP
#                 (VBD proved)
#                 (NP
#                   (NP
#                     (NP
#                       (NN production)
#                       (VBN written)
#                       (NN contract)
#                       (NN harrison))
#                     (NP
#                       (JJ twentysecond)
#                       (MD may)
#                       (NP
#                         (CD 1840)
#                         (NP
#                           (NN consideration)
#                           (PP
#                             (VBN involved)
#                             (NP
#                               (VBN indorsed)
#                               (NP
#                                 (NN button)
#                                 (NP
#                                   (NN harrison)
#                                   (NP
#                                     (NN sumter)
#                                     (NN county)
#                                     (NP
#                                       (VBN exposed)
#                                       (NP
#                                         (VBG amounting)
#                                         (NP
#                                           (ADVP (NNS upwards))
#                                           (NP
#                                             (CD fourteen)
#                                             (CD thousand)
#                                             (NN dollar)
#                                             (VBN bargained)
#                                             (PP
#                                               (VBN sold)
#                                               (NP
#                                                 (VBG growing)
#                                                 (NN cotton)
#                                                 (RB c)
#                                                 (NP
#                                                   (VBG consisting)
#                                                   (NP
#                                                     (NP
#                                                       (NP
#                                                         (NP
#                                                           (NP
#                                                             (CD one)
#                                                             (CD
#                                                               hundred)
#                                                             (CD
#                                                               twenty)
#                                                             (NN acre))
#                                                           (IN c))
#                                                         (NP
#                                                           (NN allen)
#                                                           (NN
#                                                             harrison)))
#                                                       (VBD promised))
#                                                     (NP
#                                                       (VBN obliged)
#                                                       (VB give)
#                                                       (NP
#                                                         (NP (NN use))
#                                                         (NN time)
#                                                         (JJ save)
#                                                         (NP
#                                                           (NN
#                                                             suffering)
#                                                           (NP
#                                                             (VBN
#                                                               indorsed)
#                                                             (PP
#                                                               (VBN
#                                                                 matured)
#                                                               (IN
#                                                                 undertook)
#                                                               (VB
#                                                                 deliver)
#                                                               (NP
#                                                                 (NP
#                                                                   (NN
#                                                                     cotton)
#                                                                   (NP
#                                                                     (NNP
#                                                                       gainesville)))
#                                                                 (VBD
#                                                                   came)
#                                                                 (NP
#                                                                   (NP
#                                                                     (NN
#                                                                       tennessee))
#                                                                   (VBN
#                                                                     resided)
#                                                                   (NP
#                                                                     (NP
#                                                                       (JJ
#                                                                         first)
#                                                                       (NNP
#                                                                         september)
#                                                                       (CD
#                                                                         1840))
#                                                                     (VBG
#                                                                       bringing)
#                                                                     (NP
#                                                                       (NP
#                                                                         (NP
#                                                                           (NP
#                                                                             (NP
#                                                                               (NP
#                                                                                 (QP
#                                                                                   (QP
#                                                                                     (CD
#                                                                                       three))
#                                                                                   (CD
#                                                                                     four))
#                                                                                 (JJ
#                                                                                   white)
#                                                                                 (NN
#                                                                                   laborer))
#                                                                               (VBD
#                                                                                 took)
#                                                                               (NP
#                                                                                 (NP
#                                                                                   (NP
#                                                                                     (NN
#                                                                                       possession))
#                                                                                   (PP
#                                                                                     (NN
#                                                                                       slave)))
#                                                                                 (JJ
#                                                                                   latter)
#                                                                                 (JJ
#                                                                                   white)
#                                                                                 (NN
#                                                                                   laborer)
#                                                                                 (NN
#                                                                                   cotton)
#                                                                                 (VBN
#                                                                                   prepared)
#                                                                                 (NN
#                                                                                   market)))
#                                                                             (VBN
#                                                                               levied)
#                                                                             (NN
#                                                                               warehouse))
#                                                                           (NNP
#                                                                             gainesville))
#                                                                         (NP
#                                                                           (NN
#                                                                             plaintiff)))
#                                                                       (VBD
#                                                                         proved)
#                                                                       (NP
#                                                                         (NP
#                                                                           (NN
#                                                                             harrison))
#                                                                         (VBD
#                                                                           took)
#                                                                         (NP
#                                                                           (NP
#                                                                             (NN
#                                                                               possession))
#                                                                           (ADVP
#                                                                             (JJ
#                                                                               absent)
#                                                                             (NP
#                                                                               (VBN
#                                                                                 disposed)
#                                                                               (PP
#                                                                                 (IN
#                                                                                   without)
#                                                                                 (NP
#                                                                                   (NP
#                                                                                     (NN
#                                                                                       consent))
#                                                                                   (NP
#                                                                                     (VBN
#                                                                                       admitted)
#                                                                                     (NP
#                                                                                       (NN
#                                                                                         contract)))))))))))))))))))))))))))))))))))
#                   (VP (VBN made) (ADJP (JJ good)) (NN faith)))))))))))
# (TOP
#   (S
#     (NP
#       (NML (VBN charged) (NN jury) (NN plaintiff))
#       (NP (NN virtue) (NN judgment)))
#     (VBG growing)
#     (NP (NN harrison) (NN convey))
#     (PP (IN without) (NP (NN manner)))
#     (VBN restrained)
#     (NN writing)
#     (VBN added)
#     (NN sale)
#     (NP (JJ fiery) (NN facial))
#     (VP
#       (MD would)
#       (VP
#         (VBN attached)
#         (PP
#           (IN upon)
#           (NP (ADJP (RB yet) (VBN obtained)) (NN possession)))
#         (NP
#           (JJ first)
#           (NN september)
#           (VBN controlled)
#           (NN gathering)
#           (NP (VBN attached) (NN subject)))))))
# (TOP (NP (NN attorney) (NN law) (NN firm)))
# (TOP
#   (S
#     (NP
#       (NML (LS r) (NN h) (NNP smith))
#       (NP (NN plaintiff) (NN error)))
#     (VP
#       (VBN made)
#       (PP (VBG following) (NP (NN point)))
#       (NP (NN harrison) (MD must)))
#     (MD may)
#     (CD 1840)
#     (NP (JJ immature) (NN state))
#     (VBD insisted)
#     (NP
#       (JJ subject)
#       (NN sale)
#       (CD 2)
#       (NML (JJ common) (NN law))
#       (VBG growing))
#     (MD could)
#     (VP (VBN levied))
#     (VBN sold)
#     (CD 1)
#     (NN talk)
#     (NN rep)
#     (CD 361)
#     (CD 1)
#     (NN boy)
#     (NN p)
#     (NN rep)
#     (CD 307)
#     (CD 6)
#     (NN east)
#     (NN rep)
#     (CD 604)
#     (NN note)
#     (CD 1)
#     (CD 2)
#     (NNP john)
#     (NN rep)
#     (CD 422)
#     (CD 7)
#     (JJ mass)
#     (NN rep)
#     (CD 34)
#     (NN statue)
#     (VB ask)
#     (NN dig)
#     (CD 41)
#     (NN p)
#     (CD 167)
#     (VBZ forbids)
#     (NP
#       (NP (CD 742) (VBG growing))
#       (VB receive)
#       (NP (JJ strict) (NN construction)))
#     (ADVP (RB merely))
#     (VB inhibit)
#     (NP (JJ attache) (NN sale))
#     (MD may)
#     (VP
#       (VBN made)
#       (FRAG
#         (NP
#           (NP
#             (JJ mature)
#             (CD 3)
#             (NN contract)
#             (NN purport)
#             (VB convey)
#             (VBG growing)
#             (JJ mere)
#             (NN executor)
#             (NN agreement))
#           (VP
#             (VP
#               (VBG requiring)
#               (NP
#                 (NP
#                   (S
#                     (VP
#                       (NP
#                         (NP
#                           (NP
#                             (NP
#                               (NP
#                                 (NP
#                                   (NP
#                                     (NP
#                                       (NP
#                                         (NP (NN act))
#                                         (VBN done)
#                                         (NP
#                                           (NP
#                                             (NP
#                                               (NN harrison)
#                                               (NN order))
#                                             (VB invest)
#                                             (NN property)
#                                             (. chit)
#                                             (FW con)
#                                             (CD 112)
#                                             (CD 207)
#                                             (CD 3)
#                                             (NN john)
#                                             (NN rep))
#                                           (CD 338)
#                                           (CD 424)
#                                           (CD 5)))
#                                       (VBN went)
#                                       (NP (NN rep)))
#                                     (CD 26))
#                                   (CD 13)
#                                   (NN john)
#                                   (NN rep))
#                                 (CD 235)
#                                 (CD 8))
#                               (RB down)
#                               (NN rep))
#                             (FW 693)
#                             (NN act))
#                           (VBN done)
#                           (NN matter))
#                         (JJ liable))
#                       (VBN seized)))
#                   (NN harrison)
#                   (NN debt))
#                 (NN chancery)))
#             (S
#               (VP
#                 (MD would)
#                 (VP
#                   (VB compel)
#                   (NP
#                     (NP
#                       (JJ specific)
#                       (NN performance)
#                       (NN contract)
#                       (NN instance)
#                       (CD 4)
#                       (NN charge))
#                     (ADVP (RB also))
#                     (ADJP
#                       (ADJP
#                         (ADJP (JJ objectionable))
#                         (VBG deciding)
#                         (VBN disputed))
#                       (NN fact))))))))))))
# (TOP
#   (S
#     (FW w)
#     (FW murphy)
#     (FW w)
#     (FW g)
#     (NNS jones)
#     (VBN defendantcited)
#     (NN act)
#     (CD 1821)
#     (NN ask)
#     (NN dig)
#     (CD 167)
#     (VP
#       (VBZ declares)
#       (S
#         (ADJP
#           (S
#             (ADJP
#               (S (ADJP (JJ lawful) (VBN planted)))
#               (VBN contended)
#               (VBN attached)
#               (NN favor)))
#           (NP
#             (NP (NN plaintiff) (NN defendant))
#             (VP
#               (VBN restrained)
#               (S (VP (VBG making) (NP (NN contract)))))))))))
# (TOP
#   (S
#     (NP (CD 2) (VBN destroyed) (NN injunction))
#     (VB take)
#     (PRT (RP away))
#     (ADVP (RB short))
#     (SBAR
#       (WHADVP (WRB whenever))
#       (ADJP (RB temporarily) (VBN suspended)))
#     (VBN withdrawn)
#     (NN time)
#     (VBN lost)
#     (SBAR
#       (SBAR (IN while) (NP (NN foot)))
#       (CD 2)
#       (NN john)
#       (NN rep)
#       (CD 216)
#       (CD 3)
#       (VB wash)
#       (FW c)
#       (FW c)
#       (NN rep)
#       (CD 66)
#       (CD 4)
#       (NN rep)
#       (CD 130))))
# (TOP
#   (S
#     (NP
#       (NP (VBN admitted) (NN contract) (NN defendant))
#       (NP
#         (NML (JJ good) (NN faith) (NN severance) (NN removal))
#         (NN cotton)))
#     (VP
#       (VBD gave)
#       (NP (JJ latter))
#       (NP (NP (JJ good) (NN title) (NN creditor)) (NP (JJ former))))))
# (TOP (NP (NN opinion)))
# (TOP (NP (NN soldier) (FW c) (FW j)))
# (TOP
#   (NP
#     (VB doubt)
#     (VBG growing)
#     (NN existence)
#     (JJ subject)
#     (NN matter)
#     (NN sale)
#     (NP (NN mortgage) (NN contract))
#     (VBP posse)
#     (NP (NN interest) (NN vest) (NN possession))
#     (ADVP (CC either) (RB immediately))
#     (NP
#       (NP (JJ future) (NN time) (NN proposition))
#       (ADVP (RB frequently))
#       (VBN assumed)
#       (JJ unquestionable)
#       (NN point)
#       (NN inquiry))
#     (ADVP (RB generally))
#     (SBAR
#       (IN whether)
#       (S
#         (NP (NN statute) (NN fraud))
#         (CD 29)
#         (FW chas)
#         (CD 2)
#         (NP
#           (NP (JJ mere) (NN chattel) (JJ transferrable) (NN patrol))
#           (PP
#             (IN without)
#             (S
#               (VP
#                 (VBG writing)
#                 (NP
#                   (NP (JJ chatty) (NN con))
#                   (NP (QP (CD 2412) (CD 332))))))))
#         (IN while)
#         (S
#           (S
#             (NN foot)
#             (CD 2)
#             (NNP john)
#             (RB rep)
#             (CD 422)
#             (NN stewart)
#             (NNP doughy)
#             (CD 9)
#             (NN john)
#             (NN rep)
#             (QP (CD 112) (CD 743))
#             (NN austin)
#             (NN lawyer)
#             (CD 9)
#             (NN cow)
#             (NN rep)
#             (CD 39))
#           (VB see)
#           (ADVP (RB also))
#           (NP
#             (NP
#               (NP
#                 (NN lee)
#                 (NN alton)
#                 (JJ last)
#                 (NN term)
#                 (, contract)
#                 (VBN set)
#                 (NN bill)
#                 (NN exception))
#               (VB think)
#               (NP (NN evidence)))
#             (ADVP (RB rather))
#             (NP
#               (NP
#                 (NP
#                   (NP
#                     (NP
#                       (NP
#                         (NP
#                           (NP
#                             (NP
#                               (NP
#                                 (NN mortgage)
#                                 (JJ absolute)
#                                 (NN sale)
#                                 (NN recite))
#                               (VBN involved)
#                               (VBN indorsed)
#                               (. mercantile)
#                               (. firm)
#                               (NN defendant)
#                               (NN partner))
#                             (NNS upwards)
#                             (NP
#                               (NML
#                                 (NP
#                                   (NML
#                                     (NML
#                                       (CD fourteen)
#                                       (CD thousand)
#                                       (NN dollar))
#                                     (NN estate)
#                                     (NN sheriff))
#                                   (NN hand)
#                                   (NN conveyance))
#                                 (VBN made)
#                                 (NML
#                                   (NML (NN cotton) (NN corn))
#                                   (NN oat)))
#                               (NN grant)))
#                           (NNS agrees))
#                         (VB give)
#                         (NP (PP (NN time)) (NN use)))
#                       (VB prevent)
#                       (NP (NN injury) (VBN indorsed) (NN defendant)))
#                     (MD might)
#                     (NN time))
#                   (VBN divested)
#                   (NN interest)
#                   (NN contract))
#                 (VBN vested)
#                 (VBG discharging)
#                 (NN liability)
#                 (VBN indorsed)
#                 (NN judgment)
#                 (NN creditor))
#               (VP
#                 (MD might)
#                 (VBN satisfied)
#                 (NP (VBN levied) (VBN sold) (JJ fiery) (NN facial))))))))))
# (TOP
#   (S
#     (VP
#       (VB consider)
#       (S
#         (VP
#           (VBG writing)
#           (VB assert)
#           (NP
#             (NML (NN mortgage) (NN power))
#             (NN possession)
#             (NN time)
#             (NN year))
#           (IN unless)
#           (S
#             (S
#               (NP
#                 (NP (JJ relieved) (NN engagement))
#                 (VBN indorsed)
#                 (NP
#                   (NP (VBN pretended) (NN liability))
#                   (NP (JJ satisfied) (VBN admitted) (NN party))))
#               (VBD acted)
#               (UCP (JJ good) (NN faith)))
#             (JJ dry)
#             (NN question)
#             (NN law)
#             (SBAR
#               (IN whether)
#               (S
#                 (NP (NN plaintiff))
#                 (VP
#                   (MD shall)
#                   (VP
#                     (VB prevail)
#                     (S
#                       (VP
#                         (VBG assuming)
#                         (SBAR
#                           (S
#                             (SBAR
#                               (S
#                                 (SBAR
#                                   (S
#                                     (NP (JJ present) (NN plaintiff))
#                                     (VP
#                                       (VB operate)
#                                       (PP
#                                         (IN upon)
#                                         (NP
#                                           (VBN planted)
#                                           (JJ previous)
#                                           (NN contract))))))
#                                 (MD may)
#                                 (NP (CD 1840))))
#                             (VP
#                               (VB inquire)
#                               (SBAR
#                                 (IN whether)
#                                 (S
#                                   (NP (NN defendant) (NN interest))
#                                   (VP
#                                     (MD could)
#                                     (VP (VBN levied) (PP (VBN sold)))))))))))))))))))))
# (TOP
#   (SINV
#     (NP
#       (NP
#         (JJ previous)
#         (VBN taken)
#         (NN possession)
#         (VBN prepared)
#         (NN cotton)
#         (NN market))
#       (VBN removed)
#       (NP (NN warehouse) (NN possession)))
#     (VBD insisted)
#     (SBAR
#       (S
#         (NP
#           (NN trespass)
#           (VBN acquired)
#           (NN absence)
#           (NP (NN defendant)))
#         (PP (IN without) (NP (NN consent)) (VP (VBN given)))))
#     (VBG conceding)
#     (NP (NN truth) (NN fact))
#     (VBN stated)
#     (NP (NN bill) (NN exception))
#     (VBP think)
#     (VB follow)
#     (NN possession)
#     (RB nullify)
#     (MD must)
#     (VBN considered)
#     (NP (RB never) (VBN interfered) (NN contract))
#     (VBZ contains)
#     (NP (JJ express) (NN undertaking))
#     (VB give)
#     (NN time)
#     (MD might)
#     (VP
#       (VB require)
#       (NP (NN indemnity))
#       (VBN took)
#       (NN possession)
#       (NN absence)
#       (NN grant)
#       (IN though)
#       (PP (IN without) (NP (NN consent)))
#       (ADVP (RB subsequently))
#       (VP
#         (VBN acquiesced)
#         (NP
#           (NP (NN inference))
#           (MD would)
#           (NP (JJ necessary) (NN act)))
#         (VP
#           (VP
#             (VBN approved)
#             (VBG taking)
#             (NP (JJ clear) (CD 744) (NN law))
#             (VP
#               (VBN seen)
#               (NP (NN defendant))
#               (NN time)
#               (NN nothing)
#               (VP
#                 (JJ mere)
#                 (JJ equitable)
#                 (VB redeem)
#                 (NP (NN cotton))
#                 (VP
#                   (VBG paying)
#                   (NP
#                     (NP
#                       (NP (NN debt) (VBN indorsed) (NN possession))
#                       (VBN coupled)
#                       (NN equity))
#                     (NP (NP (JJ naked) (NN equity)) (VP (VBN held))))))))
#           (MD can)
#           (MD not)
#           (VP
#             (VBN reached)
#             (NP (JJ ordinary) (NN person))
#             (NN elliott)
#             (NNP hayfield)
#             (CD 5)
#             (NN porter)
#             (NN rep)
#             ('' 182)))))))
# (TOP
#   (SINV
#     (NP (CD 3))
#     (VBZ brings)
#     (NP
#       (NP (PRP u))
#       (ADVP (RB back) (NN question))
#       (IN whether)
#       (NP (NN plaintiff) (VBG growing) (NN defeat) (NN mortgage)))
#     (ADVP (RB frequently))
#     (VP
#       (VP
#         (VBD looted)
#         (SBAR
#           (IN whether)
#           (S
#             (NP
#               (NML (JJ common) (NN law))
#               (NN corn)
#               (IN c)
#               (VBD seized)
#               (NP (JJ fiery) (NN facial))
#               (FW mr)
#               (NNP dane))
#             (VP (VBG remarking) (PP (IN upon) (NP (NN point)))))))
#       (VP
#         (VBP say)
#         (SBAR
#           (S
#             (NP
#               (NP (JJ american) (NN editor))
#               (NN bacon)
#               (NN abridgment))
#             (VP
#               (VBP say)
#               (SBAR
#                 (S
#                   (NP
#                     (NP
#                       (NN wheat)
#                       (VBG growing)
#                       (NN ground)
#                       (JJ chattel)
#                       (NN subject))
#                     (VBN taken)
#                     (NP (NN sheriff)))
#                   (MD may)
#                   (VP
#                     (VB suffer)
#                     (NP (VB grow) (NN harvest) (VBN cut)))
#                   (NN sell)
#                   (VP
#                     (MD may)
#                     (ADVP (RB perhaps))
#                     (VP
#                       (VB sell)
#                       (NP
#                         (NP (VBG growing) (NN purchaser))
#                         (JJ entitled)
#                         (VB enter)
#                         (NP (NN purpose))
#                         (VBG cutting)
#                         (S
#                           (VP
#                             (VBG carrying)
#                             (ADVP (RB away))
#                             (NP
#                               (NP (NN city))
#                               (SBAR
#                                 (IN while)
#                                 (NP
#                                   (NP (NN foot))
#                                   (RB ut)
#                                   (RB supra)
#                                   (ADVP (RB also))
#                                   (NP
#                                     (NN pole)
#                                     (NN talk)
#                                     (CD 368)
#                                     (CD 1)
#                                     (NN boy)
#                                     (RB p)
#                                     (CD 397)
#                                     (CD 6)
#                                     (NN east)
#                                     (CD 604)
#                                     (. n)
#                                     (PP
#                                       (IN while)
#                                       (NP
#                                         (NP (NN foot))
#                                         (PP
#                                           (VBZ seems)
#                                           (NP
#                                             (NN support)
#                                             (NN position)
#                                             (NP
#                                               (NP
#                                                 (JJ unripe)
#                                                 (NN wheat)
#                                                 (NN corn))
#                                               (PP
#                                                 (MD may)
#                                                 (S
#                                                   (VP
#                                                     (VBN taken)
#                                                     (NP
#                                                       (NN editor)
#                                                       (NP
#                                                         (NN state)
#                                                         (NP
#                                                           (NN
#                                                             nothing)
#                                                           (VBN taken)
#                                                           (IN can)
#                                                           (RB not)
#                                                           (NP
#                                                             (VBN
#                                                               sold)
#                                                             (NN
#                                                               position)
#                                                             (VB say)
#                                                             (NP
#                                                               (NP
#                                                                 (VBN
#                                                                   learned)
#                                                                 (NN
#                                                                   commentator))
#                                                               (NP
#                                                                 (VB
#                                                                   doubt)
#                                                                 (NP
#                                                                   (NP
#                                                                     (NP
#                                                                       (NN
#                                                                         law)
#                                                                       (NP
#                                                                         (JJ
#                                                                           unnecessary)
#                                                                         (VB
#                                                                           consider)
#                                                                         (NP
#                                                                           (VB
#                                                                             matter)
#                                                                           (NP
#                                                                             (VB
#                                                                               stand)
#                                                                             (NP
#                                                                               (NP
#                                                                                 (NP
#                                                                                   (JJ
#                                                                                     common)
#                                                                                   (NN
#                                                                                     law))
#                                                                                 (JJ
#                                                                                   first)
#                                                                                 (NN
#                                                                                   section)
#                                                                                 (NN
#                                                                                   act))
#                                                                               (''
#                                                                                 1821)
#                                                                               (VB
#                                                                                 prevent)
#                                                                               (NP
#                                                                                 (NP
#                                                                                   (NN
#                                                                                     sheriff)
#                                                                                   (NN
#                                                                                     officer))
#                                                                                 (S
#                                                                                   (VP
#                                                                                     (VBG
#                                                                                       levying)
#                                                                                     (NP
#                                                                                       (NP
#                                                                                         (NN
#                                                                                           execution))
#                                                                                       (NP
#                                                                                         (JJ
#                                                                                           certain)
#                                                                                         (NN
#                                                                                           case)
#                                                                                         (NP
#                                                                                           (NNS
#                                                                                             enacts)
#                                                                                           (MD
#                                                                                             shall)
#                                                                                           (NP
#                                                                                             (JJ
#                                                                                               lawful)
#                                                                                             (NN
#                                                                                               sheriff)
#                                                                                             (NN
#                                                                                               officer)
#                                                                                             (VB
#                                                                                               writ)
#                                                                                             (NP
#                                                                                               (NP
#                                                                                                 (JJ
#                                                                                                   fiery)
#                                                                                                 (NN
#                                                                                                   facial)
#                                                                                                 (VBN
#                                                                                                   planted)
#                                                                                                 (NN
#                                                                                                   debtor)
#                                                                                                 (NN
#                                                                                                   person))
#                                                                                               (MD
#                                                                                                 may)
#                                                                                               (NP
#                                                                                                 (VB
#                                                                                                   issue)
#                                                                                                 (VB
#                                                                                                   ask)
#                                                                                                 (NP
#                                                                                                   (VB
#                                                                                                     dig)
#                                                                                                   (CD
#                                                                                                     167)
#                                                                                                   (NP
#                                                                                                     (JJ
#                                                                                                       express)
#                                                                                                     (NN
#                                                                                                       inhibition)
#                                                                                                     (VBZ
#                                                                                                       remains)
#                                                                                                     (NP
#                                                                                                       (NP
#                                                                                                         (NN
#                                                                                                           ground)
#                                                                                                         (VBN
#                                                                                                           severed)
#                                                                                                         (NN
#                                                                                                           soil))
#                                                                                                       (VBZ
#                                                                                                         owes)
#                                                                                                       (NP
#                                                                                                         (NP
#                                                                                                           (NN
#                                                                                                             growth))
#                                                                                                         (NP
#                                                                                                           (NN
#                                                                                                             respect)
#                                                                                                           (NP
#                                                                                                             (NP
#                                                                                                               (NN
#                                                                                                                 property))
#                                                                                                             (ADVP
#                                                                                                               (ADVP
#                                                                                                                 (RB
# ...
#                                                                                                 postpone)
#                                                                                               (NP
#                                                                                                 (VB
#                                                                                                   relate)
#                                                                                                 (VB
#                                                                                                   postpone)
#                                                                                                 (NP
#                                                                                                   (NN
#                                                                                                     event)
#                                                                                                   (.
#                                                                                                     take)
#                                                                                                   (NN
#                                                                                                     place))))))))))))))))))))))))))))))))))))))))))))))))))
# (TOP
#   (S
#     (CD 4)
#     (VP
#       (VBN planted)
#       (ADJP (RB expressly) (VBN taken) (RP away))
#       (NN statute)
#       (VP
#         (VP
#           (VBN connected)
#           (JJ consequent)
#           (IN upon)
#           (ADVP (RB never))
#           (VB attache)
#           (NP (NN severance) (NN defendant)))
#         (VP
#           (VB make)
#           (S
#             (NP
#               (NP (NP (NN contract)) (JJ unquestionable) (NN title))
#               (VBN coupled)
#               (NN possession))
#             (ADJP
#               (ADJP (JJ paramount))
#               (VP (MD could) (VP (VB exert))))))))))
# (TOP
#   (S
#     (NP (NN circuit) (NN judge))
#     (VP
#       (MD may)
#       (NP (JJ mistaken) (NN law))
#       (VBG supposing)
#       (NP
#         (NP (NN contract))
#         (NN sale)
#         (NN error)
#         (VB respect)
#         (NP (NN material)))
#       (SBAR
#         (IN whether)
#         (S
#           (NN sale)
#           (NN mortgage)
#           (CD 746)
#           (VBN seen)
#           (NN fact)
#           (SBAR
#             (S
#               (SBAR
#                 (S
#                   (NP (NN defendant) (NN interest))
#                   (VP (MD could) (VP (VBN seized)))))
#               (VBN sold)))
#           (NN assumption)
#           (NML (JJ material) (NN fact) (NN charge))
#           (NN possession)
#           (NN claimant)
#           (NP (NP (NN time)) (VP (VBN acquired) (NP (NN gathering))))
#           (FW c)
#           (NP (VBN referred) (NN determination) (NN jury))
#           (VP
#             (VP (VBD instructed))
#             (VP
#               (VB find)
#               (PP
#                 (VBG according)
#                 (NP
#                   (NP (NN evidence))
#                   (VP
#                     (VBN added)
#                     (SBAR
#                       (S
#                         (NP
#                           (ADJP (RB ever) (VBN attached))
#                           (NN favor)
#                           (NN plaintiff)
#                           (NN bone)
#                           (NN side)
#                           (NN contract)
#                           (VBN conceded)
#                           (NN charge)
#                           (NP (JJ necessary) (NN point)))
#                         (VP
#                           (MD could)
#                           (VP
#                             (NP (NN propriety))
#                             (VP
#                               (VB enter)
#                               (NP (NN inquiry) (NN jury)))))))))))))))))
# (TOP
#   (SINV
#     (NP (NN result))
#     (VP (VBD said))
#     (NP (NN judgment) (NN circuit))
#     (VP (VBD affirmed))))
# (TOP (NP (JJ dissenting) (NN opinion)))
# (TOP (NP (NN mormon) (NNP j)))
# (TOP
#   (S
#     (NP (CD 4) (ADJP (NN statute) (JJ present)) (NN question))
#     (MD shall)
#     (NP
#       (NP (JJ lawful) (NN sheriff) (NN officer))
#       (VP
#         (VB writ)
#         (NP
#           (JJ free)
#           (ADJP (RB facial) (VBN planted))
#           (NN debtor)
#           (NN person))))
#     (VP
#       (MD may)
#       (VP (VB issue) (NP (NN class) (NN dig) (CD 210) (CD 46))))))
# (TOP
#   (VP
#     (MD shall)
#     (VP
#       (VB enter)
#       (PP (IN upon) (NP (NN enquiry)))
#       (SBAR
#         (IN whether)
#         (S
#           (NP (JJ common) (NN law))
#           (VP
#             (MD could)
#             (VP
#               (VP (VBN levied) (PP (IN upon) (S (VP (VBG growing)))))
#               (SBAR
#                 (IN though)
#                 (S
#                   (NP (NN apprehend))
#                   (VP
#                     (MD would)
#                     (ADVP (RB difficult))
#                     (VB maintain)
#                     (NP (JJ affirmative) (NN proposition))
#                     (NP
#                       (NP (JJ sufficient) (NN purpose))
#                       (NP (NN statute))
#                       (VP
#                         (VBZ supposes)
#                         (NP
#                           (NP (NN law))
#                           (NP (JJ doubtless) (NN practice)))))))))))))))
# (TOP
#   (S
#     (NP (NN act))
#     (MD must)
#     (VBN considered)
#     (NP
#       (NP (NN connection) (NN act))
#       (PP
#         (PP (IN upon) (NP (JJ subject) (NN state)))
#         (VBN indicated)
#         (NP (NN statute))
#         (ADVP (RB undeniably))
#         (NN property)
#         (NN debtor)
#         (JJ real)
#         (JJ personal)
#         (JJ legal)
#         (NN title)
#         (VP (MD shall) (VP (JJ subject) (NN sale) (VBZ appears))))
#       (MD would)
#       (JJ difficult)
#       (VB assign)
#       (NN reason)
#       (NN exemption)
#       (JJ specie)
#       (NN property)
#       (NN claim)
#       (NN judgment)
#       (NP (NN creditor))
#       (VP
#         (VP (VP (VBG giving) (NP (NN defendant))) (VB dispose))
#         (VBZ appears))
#       (NN deference)
#       (NN argument)
#       (SBAR
#         (S
#           (NP (NN sheriff))
#           (VP
#             (VBD prohibited)
#             (S
#               (VP
#                 (VBG levying)
#                 (VP
#                   (ADVP (S (VP (VBN planted))) (ADVP (RB therefore)))
#                   (NP (VBN lost) (NN debtor)))))
#             (VB sell)
#             (NP
#               (ADJP (RB non) (JJ sequitur) (JJ mischief))
#               (NN statute))
#             (VP
#               (VBN designed)
#               (NN remedy)
#               (NN sacrifice)
#               (VP
#                 (MD would)
#                 (ADVP (RB necessarily))
#                 (VP
#                   (VBN made)
#                   (S
#                     (NP (NN sale) (JJ immature) (NN statute))
#                     (VP
#                       (VBZ enables)
#                       (NP (NN debtor))
#                       (VP
#                         (VB retain)
#                         (JJ mature)
#                         (JJ severing)
#                         (NN soil)
#                         (VBN put)
#                         (CD 747)
#                         (NN condition)
#                         (VB bring)
#                         (NP
#                           (DT valuethe)
#                           (JJ mean)
#                           (NN time)
#                           (VP (VBG continuing) (NP (NN plaintiff))))))))))))))))
# (TOP
#   (S
#     (NP (CD 5) (NN confirmation) (NN correctness) (NN view))
#     (JJ necessary)
#     (VBN found)
#     (NN think)
#     (S
#       (NP
#         (NN language)
#         (VBN employed)
#         (NN legislature)
#         (ADJP (NN sheriff) (VBN forbidden))
#         (VBN planted)
#         (NN view)
#         (VBN taken)
#         (NN majority)
#         (JJ correct)
#         (VBN secured)
#         (NN plaintiff)
#         (VBG levying))
#       (VP
#         (MD may)
#         (VP
#           (VB frustrated)
#           (NP (NN sale) (NN defendant))
#           (SBAR
#             (IN whilst)
#             (S
#               (NP
#                 (NP (JJ immature) (NN state) (NN construction))
#                 (VP (VBN put) (PP (IN upon) (NP (NN statute)))))
#               (VP
#                 (VBZ involves)
#                 (NML (JJ singular) (NN animal) (NN legislature))
#                 (NN protection)
#                 (ADJP (NN debtor) (VBN forbidden))
#                 (NN plaintiff)
#                 (VP
#                   (VB sell)
#                   (NP
#                     (NP (NN property) (NN debtor) (NN condition))
#                     (VP (VBP bring) (NP (NN value))))))
#               (CC yet)
#               (VB permit)
#               (S
#                 (NP (NN debtor))
#                 (ADVP (RB voluntarily))
#                 (VB sale)
#                 (VB submit)
#                 (NP
#                   (NP
#                     (NN sacrifice)
#                     (NN benefit)
#                     (NN effect)
#                     (NN gift)
#                     (NN defendant))
#                   (VP
#                     (VBG growing)
#                     (VBN provided)
#                     (NP (VB gather) (VBN disposed) (NN condition)))))
#               (VB feel)
#               (NP
#                 (NP
#                   (JJ thorough)
#                   (NN conviction)
#                   (NN intention)
#                   (NP (NN legislature) (JJ secure) (NN loss)))
#                 (VP
#                   (VBG prohibiting)
#                   (NP
#                     (NN sale)
#                     (NP (JJ temporary) (NN suspension))
#                     (VB sell))
#                   (VP (VBD ceased)))))))))))
# (TOP (NP (NN situation)))
# (TOP
#   (NP
#     (NP (NP (CD 5)) (NP (DT all) (CD 740) (CD 1843)))
#     (NP (PRP we))
#     (NP (CD 284))))
# (TOP (NP (NN end) (NN document)))
# (TOP
#   (NP
#     (NP (CD 2019) (NP (NN thomson) (NN renter)))
#     (VP
#       (VB claim)
#       (NP (JJ original) (FW u) (NN government) (NN work)))))
# (TOP (NP (NN biting) (NN reference) (CD 9)))
# (TOP (NP (NN treatment)))
# (TOP (NP (NN title)))
# (TOP (NP (NN date)))
# (TOP (S (VP (VB type))))
# (TOP (NP (NN depth)))
# (TOP (NP (NNS headnotes)))
# (TOP (VP (VBN cited)))
# (TOP (S (NP (CD 1) (NN hooker)) (VP (VBZ jones) (NP (NN army)))))
# (TOP (NP (NP (CD 55) (DT all) (CD 266) (CD 271)) (NP (DT all))))
# (TOP
#   (S
#     (NP
#       (NML (NN grover) (NN conversion))
#       (NML (NN cotton) (NN count))
#       (NN appeal)
#       (NN circuit))
#     (RB hale)
#     (VP (VBN tried) (NP (IN hon) (IN j) (NN scaffold)))))
# (TOP (NP (NP (JJ dec) (NN term)) (NP (CD 1876))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN cited)))
# (TOP (NP (CD 2) (JJ german) (NN burr) (NN co) (NN marshall)))
# (TOP (NP (NP (CD 47)) (NP (DT all) (CD 362) (CD 376) (NP (DT all)))))
# (TOP
#   (S
#     (NML (NN grover) (NN conversion))
#     (NML (NN cotton) (NN appeal))
#     (NN city)
#     (NN montgomery)
#     (VP (VBD tried) (NP (IN hon) (NN john) (NNP cunningham)))))
# (TOP (NP (NP (JJ jan) (NN term)) (NP (CD 1872))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN cited)))
# (TOP (NP (CD 3) (NN gibb) (NN manner)))
# (TOP (NP (NP (CD 45)) (NP (DT all) (CD 329) (CD 334) (NP (DT all)))))
# (TOP
#   (S
#     (NN banishment)
#     (NML (NML (NN wage) (NN waiter)) (NN exemption))
#     (NN appeal)
#     (NN city)
#     (NN montgomery)
#     (VP (VBD tried) (NP (IN hon) (NN john) (NNP cunningham)))))
# (TOP (NP (NP (JJ jan) (NN term)) (NP (CD 1871))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN cited)))
# (TOP (NP (NP (CD 4) (NN mckenzie)) (ADJP (JJ ample))))
# (TOP (NP (NP (CD 31)) (NP (DT all) (CD 526) (CD 527) (NP (DT all)))))
# (TOP
#   (S
#     (NP
#       (NML
#         (NML (NN trial) (NN property))
#         (NN cotton)
#         (NN appeal)
#         (NN circuit))
#       (NN harbour))
#     (VP (VBD tried) (NP (VB hon) (RB hale)))))
# (TOP (NP (NP (JJ jan) (NN term)) (NP (CD 1858))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN cited)))
# (TOP (ADVP (NP (CD 5) (NNS evans)) (ADVP (RB later))))
# (TOP (NP (NP (CD 21)) (DT all) (CD 333) (CD 335) (NP (DT all))))
# (TOP
#   (S
#     (NP (NN error) (NN circuit) (FW autauga))
#     (VP (VBD tried) (NP (NN hon) (FW b) (NN moore)))))
# (TOP (NP (NP (NN run) (NN term)) (NP (CD 1852))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN cited)))
# (TOP (NP (CD 6) (JJ dewey) (NN woman)))
# (TOP (NP (NP (CD 8) (NN cal)) (NP (CD 145) (CD 147) (NN cal))))
# (TOP
#   (S
#     (NP (NP (NN judgment)) (NN jacob) (NNP cohens))
#     (VP
#       (VBD reversed)
#       (PP
#         (VBG following)
#         (NP
#           (NN reason)
#           (VBG finding)
#           (NP (NP (RB far) (NNS cohens)) (ADJP (VBN concerned))))))))
# (TOP (NP (NP (JJ july) (NN term)) (NP (CD 1857))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN mentioned)))
# (TOP (NP (CD 7) (NN tree) (NN coat)))
# (TOP (NP (NP (CD 65)) (DT all) (CD 256) (CD 258) (NP (DT all))))
# (TOP
#   (S
#     (NP
#       (NP (NN grover) (NN conversion))
#       (NML (CD three) (NN bale))
#       (NN cotton)
#       (NN appeal)
#       (NN circuit))
#     (VP (VBN tried) (NP (IN hon) (FW wm) (FW l) (NN whitlow)))))
# (TOP (NP (NP (NNP nov) (NN term)) (NP (CD 1880))))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (VP (VBN mentioned)))
# (TOP (NP (CD 8) (NN edward) (NN thompson)))
# (TOP (NP (NP (CD 4) (NNS s)) (CD 913) (CD 914) (FW tenn)))
# (TOP (S (NP (NN appeal) (NN circuit)) (NP (RB weakly) (NN county))))
# (TOP (NP (MD may) (NP (CD 1887))))
# There is no Parse Tree
# There is no Parse Tree
# There is no Parse Tree
# (TOP
#   (NP
#     (NP (CD 9) (VBG growing) (NN crop) (NN subject))
#     (NP (NN seizure) (NN attachment))))
# (TOP (NP (NP (CD 103)) (NP (DT all) (CD 464))))
# (TOP
#   (S
#     (NP
#       (NML (RB generally) (JJ common) (NN law))
#       (VBG growing)
#       (NN crop))
#     (VP
#       (VBD raised)
#       (NP
#         (NP (JJ annual) (NN planting))
#         (ADVP (ADJP (ADVP (RB still)) (VBN attached)) (NN soil)))
#       (VP
#         (VBD regarded)
#         (NP
#           (NML (JJ personal) (NN chattel) (NN subject))
#           (NN seizure)
#           (NN attachment))))))
# (TOP (NP (CD 1936)))
# (TOP (NP (DT all)))
# There is no Parse Tree
# There is no Parse Tree
# (TOP (NP (NN table) (NN authority) (CD 3)))
# (TOP (NP (NN treatment)))
# (TOP (NP (NN reference) (NN title)))
# (TOP (S (VP (VB type))))
# (TOP (NP (NN depth)))
# (TOP (S (VP (VBN quoted))))
# (TOP (NP (NN page) (NN number)))
# (TOP (VP (VBN mentioned)))
# (TOP (NP (CD 1) (NN austin) (NN lawyer)))
# (TOP (NP (NP (NP (CD 9) (NN cow)) (CD 39)) (IN sup) (NP (CD 1828))))
# (TOP
#   (S
#     (NP (NP (NN patrol) (NN evidence)) (ADJP (JJ admissible)))
#     (VP
#       (VBP contradict)
#       (NP
#         (NP (ADJP (RB substantially) (VBN written)) (NN contract))
#         (NP
#           (NP (VBN quitclaimed) (NN land))
#           (PP
#             (IN w)
#             (NP (NP (NN wheat)) (VP (VBG growing) (VBG reserving)))))))))
# There is no Parse Tree
# (TOP (NP (CD 2)))
# (TOP (VP (VBN cited)))
# (TOP (NP (NML (CD 2) (NN person)) (NN hayfield)))
# (TOP (NP (NP (CD 5) (NN port) (CD 182)) (NP (DT all) (CD 1837))))
# (TOP
#   (NP (NP (NML (NN writ) (NN error)) (NN circuit)) (FW tuskaloosa)))
# There is no Parse Tree
# (TOP (NP (CD 2)))
# (TOP (VP (VBN mentioned)))
# (TOP (NP (CD 3) (NN stewart) (JJ doughy)))
# (TOP (NP (NP (CD 9) (NN john) (CD 108)) (IN sup) (NP (CD 1812))))
# (TOP
#   (VP
#     (VB let)
#     (S
#       (IN b)
#       (NP
#         (NN farm)
#         (NML (CD six) (NN year))
#         (VBN agreed)
#         (NN render)
#         (NN yield))
#       (VP
#         (VB pay)
#         (NP
#           (NP
#             (QP (CD one) (PDT half))
#             (NML (NN wheat) (NN rye))
#             (NN corn)
#             (NN grain))
#           (VP (VBN raised) (NP (NN farm) (NN year))))))))
# There is no Parse Tree
# (TOP (NP (CD 2)))
# (TOP (S (VP (VBG filing))))
# (TOP (NP (NN filing) (NN situation)))
# (TOP (NP (JJ negative) (NN treatment)))
# (TOP
#   (S
#     (NP (JJ negative) (NN treatment))
#     (VP (VBP result) (NP (NN situation)))))
# (TOP (NP (NN history)))
# (TOP (NP (NP (NN history)) (VP (NN result) (NN situation))))

# %%
# Dependency parsing
import spacy
from spacy import displacy

n = spacy.load("en_core_web_sm")
options = {'compact': True, 'font': 'Source Sans Pro', 'distance': 100}
for i in df['Text Data']:
    d = n(str(i))
    displacy.render(d, style = 'dep', options=options, jupyter=True)
# Out:
# C:\Users\ttp0037\Anaconda3\lib\site-packages\spacy\util.py:833: UserWarning: [W095] Model 'en_core_web_sm' (3.1.0) was trained with spaCy v3.1 and may not be 100% compatible with the current version (3.2.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="db40f28156ac4210b1cfd7430efe3f73-0" class="displacy" width="550" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">5', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">all', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">740']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db40f28156ac4210b1cfd7430efe3f73-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db40f28156ac4210b1cfd7430efe3f73-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db40f28156ac4210b1cfd7430efe3f73-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db40f28156ac4210b1cfd7430efe3f73-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db40f28156ac4210b1cfd7430efe3f73-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db40f28156ac4210b1cfd7430efe3f73-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-db40f28156ac4210b1cfd7430efe3f73-0-3" stroke-width="2px" d="M362,102.0 362,85.33333333333333 447.0,85.33333333333333 447.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-db40f28156ac4210b1cfd7430efe3f73-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,104.0 L451.0,96.0 443.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4e9640614d1542c2b5a9a05c363c0327-0" class="displacy" width="450" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">suprem', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">alabama']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e9640614d1542c2b5a9a05c363c0327-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e9640614d1542c2b5a9a05c363c0327-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e9640614d1542c2b5a9a05c363c0327-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e9640614d1542c2b5a9a05c363c0327-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e9640614d1542c2b5a9a05c363c0327-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e9640614d1542c2b5a9a05c363c0327-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0ff3a8c039cb4cd2966ae2ae081f20ec-0" class="displacy" width="350" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">adam']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ff3a8c039cb4cd2966ae2ae081f20ec-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ff3a8c039cb4cd2966ae2ae081f20ec-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ff3a8c039cb4cd2966ae2ae081f20ec-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ff3a8c039cb4cd2966ae2ae081f20ec-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d963ffea45564ff1965db52a05fbf241-0" class="displacy" width="250" height="187.0" direction="ltr" style="max-width: none; height: 187.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d963ffea45564ff1965db52a05fbf241-0-0" stroke-width="2px" d="M62,52.0 62,35.33333333333333 150.0,35.33333333333333 150.0,52.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d963ffea45564ff1965db52a05fbf241-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150.0,54.0 L154.0,46.0 146.0,46.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0bd9f5a609f947838d912b5f0339c423-0" class="displacy" width="450" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">manner', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">norton']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0bd9f5a609f947838d912b5f0339c423-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0bd9f5a609f947838d912b5f0339c423-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0bd9f5a609f947838d912b5f0339c423-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0bd9f5a609f947838d912b5f0339c423-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0bd9f5a609f947838d912b5f0339c423-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0bd9f5a609f947838d912b5f0339c423-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7c02bd55e44a497eaccc21bc8075b674-0" class="displacy" width="550" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">june', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">term', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">1843']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c02bd55e44a497eaccc21bc8075b674-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 350.0,68.66666666666666 350.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c02bd55e44a497eaccc21bc8075b674-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c02bd55e44a497eaccc21bc8075b674-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c02bd55e44a497eaccc21bc8075b674-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c02bd55e44a497eaccc21bc8075b674-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c02bd55e44a497eaccc21bc8075b674-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,104.0 L258,96.0 266,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c02bd55e44a497eaccc21bc8075b674-0-3" stroke-width="2px" d="M362,102.0 362,85.33333333333333 447.0,85.33333333333333 447.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c02bd55e44a497eaccc21bc8075b674-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,104.0 L451.0,96.0 443.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bdcd8d63ceb04d4b9f843d8f41940b99-0" class="displacy" width="350" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">sycosi']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bdcd8d63ceb04d4b9f843d8f41940b99-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bdcd8d63ceb04d4b9f843d8f41940b99-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bdcd8d63ceb04d4b9f843d8f41940b99-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bdcd8d63ceb04d4b9f843d8f41940b99-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="84ea95d75200466589d653c53cdd1008-0" class="displacy" width="650" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">writ', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">error', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">circuit', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">sumter']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84ea95d75200466589d653c53cdd1008-0-0" stroke-width="2px" d="M62,152.0 62,102.0 450.0,102.0 450.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84ea95d75200466589d653c53cdd1008-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84ea95d75200466589d653c53cdd1008-0-1" stroke-width="2px" d="M162,152.0 162,135.33333333333334 244.0,135.33333333333334 244.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84ea95d75200466589d653c53cdd1008-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,154.0 L158,146.0 166,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84ea95d75200466589d653c53cdd1008-0-2" stroke-width="2px" d="M262,152.0 262,118.66666666666666 447.0,118.66666666666666 447.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84ea95d75200466589d653c53cdd1008-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,154.0 L258,146.0 266,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84ea95d75200466589d653c53cdd1008-0-3" stroke-width="2px" d="M262,152.0 262,135.33333333333334 344.0,135.33333333333334 344.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84ea95d75200466589d653c53cdd1008-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M344.0,154.0 L348.0,146.0 340.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-84ea95d75200466589d653c53cdd1008-0-4" stroke-width="2px" d="M462,152.0 462,135.33333333333334 544.0,135.33333333333334 544.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-84ea95d75200466589d653c53cdd1008-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M544.0,154.0 L548.0,146.0 540.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="493d3c4b56964b24b1339ce05e06a7f4-0" class="displacy" width="250" height="187.0" direction="ltr" style="max-width: none; height: 187.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="97.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-493d3c4b56964b24b1339ce05e06a7f4-0-0" stroke-width="2px" d="M62,52.0 62,35.33333333333333 150.0,35.33333333333333 150.0,52.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-493d3c4b56964b24b1339ce05e06a7f4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150.0,54.0 L154.0,46.0 146.0,46.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="effbb5a358eb42cabd0b7379ca0de688-0" class="displacy" width="550" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">west', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">headnot', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">2']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-effbb5a358eb42cabd0b7379ca0de688-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-effbb5a358eb42cabd0b7379ca0de688-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-effbb5a358eb42cabd0b7379ca0de688-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-effbb5a358eb42cabd0b7379ca0de688-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-effbb5a358eb42cabd0b7379ca0de688-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-effbb5a358eb42cabd0b7379ca0de688-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">parataxis</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-effbb5a358eb42cabd0b7379ca0de688-0-3" stroke-width="2px" d="M362,102.0 362,85.33333333333333 447.0,85.33333333333333 447.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-effbb5a358eb42cabd0b7379ca0de688-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,104.0 L451.0,96.0 443.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ae68a367075f4cc7a5a971be2021ceef-0" class="displacy" width="350" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">1']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ae68a367075f4cc7a5a971be2021ceef-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ae68a367075f4cc7a5a971be2021ceef-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ae68a367075f4cc7a5a971be2021ceef-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ae68a367075f4cc7a5a971be2021ceef-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e264bd9c1e27457790833701b98da4a2-0" class="displacy" width="450" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">chattel', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">mortgag']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e264bd9c1e27457790833701b98da4a2-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e264bd9c1e27457790833701b98da4a2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e264bd9c1e27457790833701b98da4a2-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e264bd9c1e27457790833701b98da4a2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e264bd9c1e27457790833701b98da4a2-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e264bd9c1e27457790833701b98da4a2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="34c06f7d59834e74b6c82453edd17503-0" class="displacy" width="350" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">crop']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34c06f7d59834e74b6c82453edd17503-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34c06f7d59834e74b6c82453edd17503-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34c06f7d59834e74b6c82453edd17503-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34c06f7d59834e74b6c82453edd17503-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="391c3a91b0804ea98beb3defbcd4c05f-0" class="displacy" width="1450" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">grow', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">exist', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">subjectmatt', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">mortgag', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">pas', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">interest', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">vest', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">posse', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">either', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">immedi', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">futur', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">time']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-0" stroke-width="2px" d="M62,302.0 62,252.0 341.0,252.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-1" stroke-width="2px" d="M162,302.0 162,285.3333333333333 235.0,285.3333333333333 235.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,304.0 L158,296.0 166,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-2" stroke-width="2px" d="M262,302.0 262,285.3333333333333 335.0,285.3333333333333 335.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,304.0 L258,296.0 266,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-3" stroke-width="2px" d="M362,302.0 362,285.3333333333333 435.0,285.3333333333333 435.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M435.0,304.0 L439.0,296.0 431.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-4" stroke-width="2px" d="M462,302.0 462,285.3333333333333 535.0,285.3333333333333 535.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,304.0 L539.0,296.0 531.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-5" stroke-width="2px" d="M562,302.0 562,285.3333333333333 635.0,285.3333333333333 635.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,304.0 L639.0,296.0 631.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-391c3a91b0804ea98beb3defbcd4c05f-0-6" stroke-width="2px" d="M562,302.0 562,268.6666666666667 738.0,268.6666666666667 738.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-391c3a91b0804ea98beb3defbcd4c05f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8848c64978db460887ff67ff5406a55e-0" class="displacy" width="650" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">4', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
# ...
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8a8278d82ee4d23805b4e424cf15984-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8a8278d82ee4d23805b4e424cf15984-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8a8278d82ee4d23805b4e424cf15984-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d8a8278d82ee4d23805b4e424cf15984-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d8a8278d82ee4d23805b4e424cf15984-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6f5b509b52de4789a13144920c7731f9-0" class="displacy" width="450" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">neg', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">treatment']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f5b509b52de4789a13144920c7731f9-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f5b509b52de4789a13144920c7731f9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f5b509b52de4789a13144920c7731f9-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f5b509b52de4789a13144920c7731f9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f5b509b52de4789a13144920c7731f9-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f5b509b52de4789a13144920c7731f9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3092ad38496f4a34b594f7ce91e950e8-0" class="displacy" width="650" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">neg', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">treatment', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">result', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">situat']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3092ad38496f4a34b594f7ce91e950e8-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3092ad38496f4a34b594f7ce91e950e8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3092ad38496f4a34b594f7ce91e950e8-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3092ad38496f4a34b594f7ce91e950e8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3092ad38496f4a34b594f7ce91e950e8-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3092ad38496f4a34b594f7ce91e950e8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,104.0 L351.0,96.0 343.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3092ad38496f4a34b594f7ce91e950e8-0-3" stroke-width="2px" d="M262,102.0 262,68.66666666666666 450.0,68.66666666666666 450.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3092ad38496f4a34b594f7ce91e950e8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,104.0 L454.0,96.0 446.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3092ad38496f4a34b594f7ce91e950e8-0-4" stroke-width="2px" d="M462,102.0 462,85.33333333333333 547.0,85.33333333333333 547.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3092ad38496f4a34b594f7ce91e950e8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M547.0,104.0 L551.0,96.0 543.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2299e998baf041c19ba6e672a370233e-0" class="displacy" width="350" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">histori']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2299e998baf041c19ba6e672a370233e-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 250.0,68.66666666666666 250.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2299e998baf041c19ba6e672a370233e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2299e998baf041c19ba6e672a370233e-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2299e998baf041c19ba6e672a370233e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8bc1602aa840437eaca0f87619817984-0" class="displacy" width="550" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">histori', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">result', '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">situat']</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bc1602aa840437eaca0f87619817984-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 350.0,68.66666666666666 350.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bc1602aa840437eaca0f87619817984-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bc1602aa840437eaca0f87619817984-0-1" stroke-width="2px" d="M162,102.0 162,85.33333333333333 247.0,85.33333333333333 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bc1602aa840437eaca0f87619817984-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bc1602aa840437eaca0f87619817984-0-2" stroke-width="2px" d="M262,102.0 262,85.33333333333333 347.0,85.33333333333333 347.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bc1602aa840437eaca0f87619817984-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M262,104.0 L258,96.0 266,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bc1602aa840437eaca0f87619817984-0-3" stroke-width="2px" d="M362,102.0 362,85.33333333333333 447.0,85.33333333333333 447.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bc1602aa840437eaca0f87619817984-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M447.0,104.0 L451.0,96.0 443.0,96.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# #### Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):

# %%
#one sentence of the constituency parsing 
sample = [sent for sent in new_data['clean_data']]
print(sample[9])

parser = benepar.Parser("benepar_en3")
tree = parser.parse(sample[9])
print(tree)
tree.pretty_print()

#one sentence of the dependency parsing 
doc = nlp(str(sample[9]))
displacy.render(doc, style = "dep", jupyter=True, options={"distance":140})
# Out:
# west headnotes 2
# (TOP (NP (NN west) (NNS headnotes) (NP (CD 2))))
#         TOP
#          |
#          NP
#   _______|______
#  |       |      NP
#  |       |      |
#  NN     NNS     CD
#  |       |      |
# west headnotes  2
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3760dfc289624854b224d006b1ed2949-0" class="displacy" width="470" height="207.0" direction="ltr" style="max-width: none; height: 207.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="117.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">west</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="117.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">headnotes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="117.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3760dfc289624854b224d006b1ed2949-0-0" stroke-width="2px" d="M70,72.0 C70,2.0 190.0,2.0 190.0,72.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3760dfc289624854b224d006b1ed2949-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,74.0 L62,62.0 78,62.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3760dfc289624854b224d006b1ed2949-0-1" stroke-width="2px" d="M210,72.0 C210,2.0 330.0,2.0 330.0,72.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3760dfc289624854b224d006b1ed2949-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M330.0,74.0 L338.0,62.0 322.0,62.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## (3) Named Entity Recognition

# %%
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
tokens = nlp(''.join(str(new_data['clean_data'].tolist())))
items = [x.text for x in tokens.ents]
Counter(items).most_common(num_rows)
# Out:
# [('5', 7),
#  ('2', 6),
#  ('4', 5),
#  ('9', 5),
#  ('6', 3),
#  ('167', 3),
#  ('3', 3),
#  ('fourteen thousand dollar', 2),
#  ('1840', 2),
#  ('1', 2),
#  ('604', 2),
#  ('112', 2),
#  ('1821', 2),
#  ('182', 2),
#  ("john cunningham'", 2),
#  ('8', 2),
#  ('740', 1),
#  ('1843', 1),
#  ('november 1840', 1),
#  ('thirtyseven hundred seventyseven 80100 dollar', 1),
#  ('thirty', 1),
#  ('october 1839', 1),
#  ('741', 1),
#  ('harrison twentysecond', 1),
#  ('may 1840', 1),
#  ('one hundred twenty acre', 1),
#  ('tennessee', 1),
#  ('september 1840', 1),
#  ('three four', 1),
#  ('first september', 1),
#  ('361 1', 1),
#  ('307', 1),
#  ('1 2', 1),
#  ('422 7', 1),
#  ('34', 1),
#  ('41', 1),
#  ('742', 1),
#  ('338', 1),
#  ('26 13', 1),
#  ('235 8', 1),
#  ('693', 1),
#  ('216', 1),
#  ('66 4', 1),
#  ('130', 1),
#  ('29', 1),
#  ('2412 332', 1),
#  ('422', 1),
#  ('743', 1),
#  ('39', 1),
#  ('lee alton', 1),
#  ('744', 1),
#  ('american', 1),
#  ('368 1 boy', 1),
#  ('first', 1),
#  ('745', 1),
#  ('united state', 1),
#  ('746', 1),
#  ('747', 1),
#  ('284', 1),
#  ('2019', 1),
#  ('55', 1),
#  ('266 271', 1),
#  ('1876', 1),
#  ('2 german', 1),
#  ('47', 1),
#  ('all 362 376', 1),
#  ('1872', 1),
#  ('45', 1),
#  ('329 334', 1),
#  ("jan term 1871'", 1),
#  ('31', 1),
#  ('526 527', 1),
#  ('1858', 1),
#  ('21', 1),
#  ('333 335', 1),
#  ('1852', 1),
#  ('jacob cohens', 1),
#  ('july', 1),
#  ('1857', 1),
#  ('65', 1),
#  ('256 258', 1),
#  ('three', 1),
#  ("nov term 1880'", 1),
#  ("edward thompson'", 1),
#  ('913 914', 1),
#  ('1887', 1),
#  ('103', 1),
#  ('annual', 1),
#  ('1936', 1),
#  ('austin', 1),
#  ("39 sup 1828'", 1),
#  ('108', 1),
#  ("sup 1812'", 1),
#  ('six year', 1),
#  ('one half', 1)]

# %%
# for PERSON groups
person_list = []
for ent in tokens.ents:
    if ent.label_ == 'PERSON':
        person_list.append(ent.text)
        
person_counts = Counter(person_list).most_common(num_rows)
df_person = pd.DataFrame(person_counts, columns =['text', 'count'])
df_person
# Out:
#                     text  count
# 0       john cunningham'      2
# 1  harrison twentysecond      1
# 2              lee alton      1
# 3           jacob cohens      1
# 4       edward thompson'      1
# 5                 austin      1

# %%
# for ORG (organization) groups
org_list = []
for ent in tokens.ents:
    if ent.label_ == 'ORG':
        org_list.append(ent.text)
        
org_counts = Counter(org_list).most_common(num_rows)
df_org = pd.DataFrame(org_counts, columns =['text', 'count'])
df_org
# Out:
#            text  count
# 0  united state      1

# %%
# for LOC (location)
loc_list = []
for ent in tokens.ents:
    if ent.label_ == 'LOC':
        loc_list.append(ent.text)
        
loc_counts = Counter(loc_list).most_common(num_rows)
df_loc = pd.DataFrame(loc_counts, columns =['text', 'count'])
df_loc
# Out:
# Empty DataFrame
# Columns: [text, count]
# Index: []

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
# You explaination here
'''
Constituency parsing is the process of analyzing the sentences by breaking down it into sub-phrases. The sub-phrases are specific category of grammar like NP (noun phrase) and VP (verb phrase)
Dependency parsing is the process of analyzing the grammatical structure of a sentence on the dependencies between the words in a sentence.
Example: "The world is one big data problem."
Constituency parsing: first level is sentence, which is splitted into NP ("The world") and VP ("is one big data problem."). The VP is divided into a VP and another NP. In this example, VP is "is" and NP is "one big data problem." And continuosly until it could not be broken anymore.
Dependency parsing: it is completely different. The root is the verb of sentence ("is"). "world" is nsubj, "one" is nummod, "big" is amod, "data" dobj, "problem" is dobj and "The" is determiner.

'''

# %% [markdown]
# # **Question 4**

# %% [markdown]
# (20 points) Python Regular Expression.
#
# (1) Write a Python program to remove leading zeros from an IP address.
#
# ip = "260.08.094.109"
#
#
# (2) Write a Python Program to extract all the years from the following sentence.
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
# Write your code here
import re 
  
# function to remove leading zeros
def removeZeros(ip):
    new_ip = re.sub(r'\b0+(\d)', r'\1', ip)
    return new_ip 

ip = input("Please enter IP address: ")
newip = removeZeros(ip)
print("IP address after remove leading zeros: ", newip)

# %%
import re
# Input.
sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# find all the words starting with '2' and store in a list
lst = re.findall("[2]\w+", sentence)

# get word that lenght = 4 and all characters are digit
list_year = []
for i in lst:
    if i.isdigit() and len(i) == 4:
        list_year.append(i)
    
print(list_year)
