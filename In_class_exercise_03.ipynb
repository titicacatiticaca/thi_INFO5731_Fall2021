# %% [markdown]
# <a href="https://colab.research.google.com/github/titicacatiticaca/thi_INFO5731_Fall2021/blob/main/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/29/2021, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
"In Text Classification Workflow, one of the steps is a feature engineering. 
In this step, raw data will be cleaned and transformed into feature vectores. 
In addiction, the new features will be created using prior dataset. 
Word level feature and sentence-level features are the features that is useful to you the SVM and Naive Bayes machine learning models.
The features are: TF-IDF vectorizer (TF-IDF, IDF, N-gram) && (POS tagging, systax analysis)" 



'''
# Out:
# '\nPlease write you answer here:\n"In Text Classification Workflow, one of the steps is a feature engineering. \nIn this step, raw data will be cleaned and transformed into feature vectores. \nIn addiction, the new features will be created using prior dataset. \nWord level feature and sentence-level features are the features that is useful to you the SVM and Naive Bayes machine learning models.\nThe features are: TF-IDF vectorizer (TF-IDF, IDF, N-gram) && (POS tagging, systax analysis)" \n\n\n\n'

# %% [markdown]
# Question 2 (20 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
listofsen = ['In Text Classification Workflow, one of the steps is a feature engineering.', 'In this step, raw data will be cleaned and transformed into feature vectores.', 'In addiction, the new features will be created using prior dataset.', 'Word level feature and sentence-level features are the features that is useful to you the SVM and Naive Bayes machine learning models.', 'The features are: TF-IDF vectorizer (TF-IDF, IDF, N-gram) && (POS tagging, systax analysis)']

# %%
import pandas as pd

data = pd.DataFrame(listofsen, columns = ['sentence'])

data
# Out:
#                                             sentence
# 0  In Text Classification Workflow, one of the st...
# 1  In this step, raw data will be cleaned and tra...
# 2  In addiction, the new features will be created...
# 3  Word level feature and sentence-level features...
# 4  The features are: TF-IDF vectorizer (TF-IDF, I...

# %%
# Removing Punctuation
data['sentence'] = data['sentence'].str.replace('[^\w\s]','')
data
# Out:
#                                             sentence
# 0  In Text Classification Workflow one of the ste...
# 1  In this step raw data will be cleaned and tran...
# 2  In addiction the new features will be created ...
# 3  Word level feature and sentencelevel features ...
# 4  The features are TFIDF vectorizer TFIDF IDF Ng...

# %%
# Tokenization
import nltk
from textblob import TextBlob
nltk.download('punkt')

TextBlob(data['sentence'][1]).words
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WordList(['In', 'this', 'step', 'raw', 'data', 'will', 'be', 'cleaned', 'and', 'transformed', 'into', 'feature', 'vectores'])

# %%
# N-grams
TextBlob(data['sentence'][0]).ngrams(2)
# Out:
# [WordList(['In', 'Text']),
#  WordList(['Text', 'Classification']),
#  WordList(['Classification', 'Workflow']),
#  WordList(['Workflow', 'one']),
#  WordList(['one', 'of']),
#  WordList(['of', 'the']),
#  WordList(['the', 'steps']),
#  WordList(['steps', 'is']),
#  WordList(['is', 'a']),
#  WordList(['a', 'feature']),
#  WordList(['feature', 'engineering'])]

# %%
# Term frequency
termfreq = (data['sentence'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
termfreq.columns = ['words','term freq']
termfreq
# Out:
#           words  term freq
# 0          step          1
# 1          data          1
# 2          this          1
# 3           and          1
# 4           raw          1
# 5          will          1
# 6            In          1
# 7      vectores          1
# 8       cleaned          1
# 9   transformed          1
# 10           be          1
# 11      feature          1
# 12         into          1

# %%
# IDF
import numpy as np

for i,word in enumerate(termfreq['words']):
    termfreq.loc[i, 'inverse_doc_freq'] = np.log(data.shape[0]/(len(data[data['sentence'].str.contains(word)])))

termfreq
# Out:
#           words  term freq  inverse_doc_freq
# 0          step          1          0.916291
# 1          data          1          0.916291
# 2          this          1          1.609438
# 3           and          1          0.916291
# 4           raw          1          1.609438
# 5          will          1          0.916291
# 6            In          1          0.510826
# 7      vectores          1          1.609438
# 8       cleaned          1          1.609438
# 9   transformed          1          1.609438
# 10           be          1          0.916291
# 11      feature          1          0.000000
# 12         into          1          1.609438

# %%
# Term Frequency – Inverse Document Frequency (TF-IDF)
termfreq['tfidf'] = termfreq['term freq'] * termfreq['inverse_doc_freq']
termfreq
# Out:
#           words  term freq  inverse_doc_freq     tfidf
# 0          step          1          0.916291  0.916291
# 1          data          1          0.916291  0.916291
# 2          this          1          1.609438  1.609438
# 3           and          1          0.916291  0.916291
# 4           raw          1          1.609438  1.609438
# 5          will          1          0.916291  0.916291
# 6            In          1          0.510826  0.510826
# 7      vectores          1          1.609438  1.609438
# 8       cleaned          1          1.609438  1.609438
# 9   transformed          1          1.609438  1.609438
# 10           be          1          0.916291  0.916291
# 11      feature          1          0.000000  0.000000
# 12         into          1          1.609438  1.609438

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 7.7 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
import en_core_web_sm
from textblob import Word
import spacy
nlp = spacy.load("en_core_web_sm")
#import en_core_web_s
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# add appropriate words that will be ignored in the analysis
ADDITIONAL_STOPWORDS = ['covfefe']

def basic_clean(text):
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english') + ADDITIONAL_STOPWORDS
    text = (unicodedata.normalize('NFKD', text)
    .encode('ascii', 'ignore')
    .decode('utf-8', 'ignore')
    .lower())
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
words = basic_clean(''.join(str(data['sentence'].tolist())))

# %%
# load english language model
nlp = spacy.load('en_core_web_sm',disable=['ner','textcat'])
nlp = en_core_web_sm.load()


# create spacy 
doc = nlp(str(words))
noun = 0
verb = 0
adj = 0
adv = 0
for token in doc:
    print(token.text,'->',token.pos_)
    if token.pos_ == 'NOUN':
      noun = noun+1
    elif token.pos_ == 'VERB':
      verb = verb+1
    elif token.pos_ == 'ADJ':
      adj = adj+1
    elif token.pos_ == 'ADV':
      adv = adv+1
    else:
      pass
print("The total nouns: ", noun)
print("The total verbs: ", verb)
print("The total adjectives: ", adj)
print("The total adverbs: ", adv)
# Out:
# [ -> PUNCT
# ' -> PUNCT
# text -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# classification -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# workflow -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# one -> NUM
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# step -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# feature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# engineering -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# step -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# raw -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# data -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# cleaned -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# transformed -> VERB
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# feature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# vectores -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# addiction -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# new -> ADJ
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# feature -> NOUN
# ' -> PUNCT
# , -> PUNCT
# ' -> PUNCT
# ...

# %%
# !pip install benepar
import nltk
import spacy
import spacy.cli
import benepar
from nltk.tree import Tree
spacy.cli.download('en_core_web_lg')
nlp = spacy.load('en_core_web_lg')
benepar.download('benepar_en2')
nltk.download('punkt')
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')
# [nltk_data] Error loading benepar_en2: Package 'benepar_en2' not found
# [nltk_data]     in index
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sample = data['sentence'][2]
print(sample)
# Out:
# In addiction the new features will be created using prior dataset

# %%
import nltk
import spacy
import plac
import random
from spacy import displacy
from __future__ import unicode_literals, print_function
from pathlib import Path

# %%
grammar1 = nltk.CFG.fromstring("""
      S -> NP VP
      VP -> V NP | V NP PP
      PP -> P NP
      NP -> pronoun
      Det -> that | this | the | a | an
      Noun -> features | dataset
      Verb -> will | created 
      Preposition -> from | in | on  """)

rd_parser = nltk.RecursiveDescentParser(grammar1)
sample = data['sentence'][2].split()
print(sample)
# Out:
# ['In', 'addiction', 'the', 'new', 'features', 'will', 'be', 'created', 'using', 'prior', 'dataset']

# %%
from spacy import displacy
displacy.render(doc,jupyter=True, options={'distance':140})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f9e5bbe027774be1b1856991b727a35f-0" class="displacy" width="6490" height="1537.0" direction="ltr" style="max-width: none; height: 1537.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1447.0">
# ...

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
# You code here (Please add comments in the code):
import sklearn


# test classification dataset
from sklearn.datasets import make_classification

# define dataset
X, y = make_classification(n_samples = 1000, n_features = 10, n_informative = 3, n_redundant = 3, random_state = 1)

# dataset
print(X.shape, y.shape)
